# %%
# Declarations
import glob
import json
import os
import numpy as np
import pandas as pd

from os.path import basename

# %%
# DataFrame name json file
nameFile = []
pathFile = []
rootFile = []

path = os.getcwd()
for root, dirs, files in os.walk(path):
    for file in files:
        if file.endswith(".json"):
            nameFile.append(file)
            pathFile.append(os.path.join(root, file))
            rootFile.append(root)
            
nameFileS = pd.Series(nameFile)
pathFileS = pd.Series(pathFile)
rootFileS = pd.Series(rootFile)

dfNF = pd.concat([nameFileS, pathFileS, rootFileS], axis=1)
dfNF.columns = ['FILE_NAME', 'FILE_PATH', 'FILE_ROOT']

# %%
print(dfNF['FILE_PATH'][0])
# Out:
# C:\Users\vitto\Desktop\github\SLIDE-x-ML-ICCD\SLIDE-x-Ingestion\Collect_Raw_Data_AND_Clean\SLIDE-x-RES\Bambu\5SGXEA7N2F45C1-Stratix-V\28x28\astar\parameters.json

# %%
# .json file loop
#df = pd.DataFrame(columns=['Function','Device','Data_Type',
#                           'Num_Sc','Range_Sc','Num_ScI','Range_ScI',
#                           'Num_Arr','Range_Arr'])

listD = ["Bambu"] # Inserisci i dispositivi che vuoi analizzare
listDT = ["int8_t"] # Inserisci i data type che vuoi analizzare

listrange = [0, 0]
listrangeI = [0, 0]
listdtI = [' ']
listdt = [' ']
listfunI = [' ']
listfun = [' ']
listdevI = [' ']
listdev = [' ']
listboardI = [' ']
listboard = [' ']

for i in range(0, len(pathFile)):
    pF = pathFile[i]

    with open(pF, 'r') as jf:
        data = jf.read()
    obj = json.loads(data)

    if os.name == 'nt':
        spR = rootFile[i].split('\\')
    else:
        spR = rootFile[i].split('/')
    function = spR[-1]
    board = spR[-3]
    
    #Device loop
    deviceList = list(obj.keys())
    deviceListR = []
    for u in range(0, len(deviceList)):
        if deviceList[u] in listD:
            deviceListR.append(deviceList[u])

    for n in range(0, len(deviceListR)):
        # Data_type loop
        device = deviceListR[n]
        dtarr = list(obj[deviceListR[n]].keys())
        
        dtarrR = []
        for u in range(0, len(dtarr)):
            if dtarr[u] in listDT:
                dtarrR.append(dtarr[u])
        
        for j in range(0, len(dtarrR)):
            dataype = dtarrR[j]
            lsubNP = (list(obj[deviceListR[n]][dtarrR[j]].keys()))
            lsubVP = (list(obj[deviceListR[n]][dtarrR[j]].values()))
            ltot = len(lsubNP)

            kl = []
            for k in range(0, ltot):
                flag = 0
                if not "[" in lsubNP[k]:
                    for keysl in lsubNP:
                        if (lsubNP[k] in keysl) and (not lsubNP[k] is keysl) and (flag == 0):          
                            flag = 1
                            kl.append(k) 

            m = 0
            for item in lsubVP:
                #print(function, lsubVP)
                if ';' in item:
                    newstr = item.split(";")[0]
                    newstr = newstr.replace("[", "")
                    newstr = newstr.replace("]", "")
                    el1 = float(newstr.split(",")[0])
                    el2 = float(newstr.split(",")[1])
                    strint = el1
                    rangeint = el2 - el1
                    lr = np.array([strint, rangeint])
                    if m in kl:
                        listrangeI = np.vstack([listrangeI, lr])
                        listdtI.append(dataype)
                        listfunI.append(function)
                        listboardI.append(board)
                        listdevI.append(device)
                    else:
                        listrange = np.vstack([listrange, lr])
                        listdt.append(dataype)
                        listfun.append(function)
                        listboard.append(board)
                        listdev.append(device)
                m = m + 1

# %%
listrangeS = pd.DataFrame(listrange)
listdtS = pd.Series(listdt)
listfunS = pd.Series(listfun)
listdevS = pd.Series(listdev)
listboardS = pd.Series(listboard)
dfS = pd.concat([listdevS, listboardS, listfunS, listdtS, listrangeS], axis=1)
dfS.columns = ['DEVICE', 'BOARD', 'FUNCTION', 'DATA_TYPE', 'DATA_START', 'DATA_RANGE']
dfS = dfS.iloc[1:]

# %%
dfS
# Out:
#    DEVICE                        BOARD      FUNCTION DATA_TYPE  DATA_START  \
# 1   Bambu     5SGXEA7N2F45C1-Stratix-V         astar    int8_t         2.0
# 2   Bambu     5SGXEA7N2F45C1-Stratix-V  binarysearch    int8_t      -127.0
# 3   Bambu     5SGXEA7N2F45C1-Stratix-V           fft    int8_t         2.0
# 4   Bambu     5SGXEA7N2F45C1-Stratix-V           fft    int8_t        -1.0
# 5   Bambu     5SGXEA7N2F45C1-Stratix-V       fibcall    int8_t         2.0
# 6   Bambu     5SGXEA7N2F45C1-Stratix-V           gcd    int8_t         2.0
# 7   Bambu     5SGXEA7N2F45C1-Stratix-V           gcd    int8_t         2.0
# 8   Bambu     5SGXEA7N2F45C1-Stratix-V   park_miller    int8_t      -126.0
# 9   Bambu     5SGXEA7N2F45C1-Stratix-V         prime    int8_t      -126.0
# 10  Bambu     5SGXEA7N2F45C1-Stratix-V          sqrt    int8_t      -126.0
# 11  Bambu     xc7a100t-1csg324-Artix-7         astar    int8_t         2.0
# 12  Bambu     xc7a100t-1csg324-Artix-7  binarysearch    int8_t      -127.0
# 13  Bambu     xc7a100t-1csg324-Artix-7           fft    int8_t         2.0
# 14  Bambu     xc7a100t-1csg324-Artix-7           fft    int8_t        -1.0
# 15  Bambu     xc7a100t-1csg324-Artix-7       fibcall    int8_t         2.0
# 16  Bambu     xc7a100t-1csg324-Artix-7           gcd    int8_t         2.0
# 17  Bambu     xc7a100t-1csg324-Artix-7           gcd    int8_t         2.0
# 18  Bambu     xc7a100t-1csg324-Artix-7   park_miller    int8_t      -126.0
# 19  Bambu     xc7a100t-1csg324-Artix-7         prime    int8_t      -126.0
# 20  Bambu     xc7a100t-1csg324-Artix-7          sqrt    int8_t      -126.0
# 21  Bambu  xc7vx690t-3ffg1930-Virtex-7         astar    int8_t         2.0
# 22  Bambu  xc7vx690t-3ffg1930-Virtex-7  binarysearch    int8_t      -127.0
# 23  Bambu  xc7vx690t-3ffg1930-Virtex-7           fft    int8_t         2.0
# 24  Bambu  xc7vx690t-3ffg1930-Virtex-7           fft    int8_t        -1.0
# 25  Bambu  xc7vx690t-3ffg1930-Virtex-7       fibcall    int8_t         2.0
# 26  Bambu  xc7vx690t-3ffg1930-Virtex-7           gcd    int8_t         2.0
# 27  Bambu  xc7vx690t-3ffg1930-Virtex-7           gcd    int8_t         2.0
# 28  Bambu  xc7vx690t-3ffg1930-Virtex-7   park_miller    int8_t      -126.0
# 29  Bambu  xc7vx690t-3ffg1930-Virtex-7         prime    int8_t      -126.0
# 30  Bambu  xc7vx690t-3ffg1930-Virtex-7          sqrt    int8_t      -126.0
# 31  Bambu    xc7z020-1clg484-Zynq-7000         astar    int8_t         2.0
# 32  Bambu    xc7z020-1clg484-Zynq-7000  binarysearch    int8_t      -127.0
# 33  Bambu    xc7z020-1clg484-Zynq-7000           fft    int8_t         2.0
# 34  Bambu    xc7z020-1clg484-Zynq-7000           fft    int8_t        -1.0
# 35  Bambu    xc7z020-1clg484-Zynq-7000       fibcall    int8_t         2.0
# 36  Bambu    xc7z020-1clg484-Zynq-7000           gcd    int8_t         2.0
# 37  Bambu    xc7z020-1clg484-Zynq-7000           gcd    int8_t         2.0
# 38  Bambu    xc7z020-1clg484-Zynq-7000   park_miller    int8_t      -126.0
# 39  Bambu    xc7z020-1clg484-Zynq-7000         prime    int8_t      -126.0
# 40  Bambu    xc7z020-1clg484-Zynq-7000          sqrt    int8_t      -126.0
#
#     DATA_RANGE
# 1        125.0
# 2        254.0
# 3          8.0
# 4          2.0
# 5          9.0
# 6        125.0
# 7        125.0
# 8        253.0
# 9        253.0
# 10       253.0
# 11       125.0
# 12       254.0
# 13         8.0
# 14         2.0
# 15         9.0
# 16       125.0
# 17       125.0
# 18       253.0
# 19       253.0
# 20       253.0
# 21       125.0
# 22       254.0
# 23         8.0
# 24         2.0
# 25         9.0
# 26       125.0
# 27       125.0
# 28       253.0
# 29       253.0
# 30       253.0
# 31       125.0
# 32       254.0
# 33         8.0
# 34         2.0
# 35         9.0
# 36       125.0
# 37       125.0
# 38       253.0
# 39       253.0
# 40       253.0

# %%
listrangeIS = pd.DataFrame(listrangeI)
listdtIS = pd.Series(listdtI)
listfunIS = pd.Series(listfunI)
listdevIS = pd.Series(listdevI)
listboardIS = pd.Series(listboardI)
dfSI = pd.concat([listdevIS, listboardIS , listfunIS, listdtIS, listrangeIS], axis=1)
dfSI.columns = ['DEVICE', 'BOARD', 'FUNCTION', 'DATA_TYPE', 'DATA_START', 'DATA_RANGE']
dfSI = dfSI.iloc[1:]

# %%
dfSI
# Out:
#    DEVICE                      BOARD       FUNCTION DATA_TYPE  DATA_START  \
# 1   Bambu   5SGXEA7N2F45C1-Stratix-V          astar    int8_t         2.0
# 2   Bambu   5SGXEA7N2F45C1-Stratix-V    bellmanford    int8_t         2.0
# 3   Bambu   5SGXEA7N2F45C1-Stratix-V         bfsdfs    int8_t         2.0
# 4   Bambu   5SGXEA7N2F45C1-Stratix-V   binarysearch    int8_t         2.0
# 5   Bambu   5SGXEA7N2F45C1-Stratix-V     bubblesort    int8_t         2.0
# ..    ...                        ...            ...       ...         ...
# 60  Bambu  xc7z020-1clg484-Zynq-7000          qsort    int8_t         2.0
# 61  Bambu  xc7z020-1clg484-Zynq-7000      quicksort    int8_t         2.0
# 62  Bambu  xc7z020-1clg484-Zynq-7000  selectionsort    int8_t         2.0
# 63  Bambu  xc7z020-1clg484-Zynq-7000     shell_sort    int8_t         2.0
# 64  Bambu  xc7z020-1clg484-Zynq-7000  straight_sort    int8_t         2.0
#
#     DATA_RANGE
# 1         26.0
# 2         26.0
# 3         26.0
# 4         26.0
# 5         26.0
# ..         ...
# 60        26.0
# 61        26.0
# 62        23.0
# 63        26.0
# 64        26.0
#
# [64 rows x 6 columns]

# %%
serS = dfS.groupby(['DATA_TYPE'])['DATA_RANGE'].max()

n = 3
ws = 10
arrlM = []
for d in range(0, len(serS)):
    arrlimt = []
    ml = 0
    w = (serS.iloc[d] - ml) // n
    for h in range(n):
        arrlimt.append(ml + h*w)
    arrlM.append(arrlimt)
    
for index, row in dfS.iterrows():
    clf = 0
    for p in range(0, len(serS)):
        if row['DATA_TYPE'] == serS.index[p]:
            ind = p
            arrl = arrlM[ind]
            for u in range(0, len(arrl)-1):
                if (row['DATA_RANGE'] > arrl[u]) and (row['DATA_RANGE'] <= arrl[u+1]):
                    clf = u + 1
                elif (row['DATA_RANGE'] > arrl[u+1]):
                    clf = len(arrl)            
    dfS['RANGE_S'] = clf

# %%
serSI = dfSI.groupby(['DATA_TYPE'])['DATA_RANGE'].max()

n = 3
ws = 10
arrlM = []
for d in range(0, len(serSI)):
    arrlimt = []
    ml = 0
    w = (serSI.iloc[d] - ml) // n
    for h in range(n):
        arrlimt.append(ml + h*w)
    arrlM.append(arrlimt)
    
for index, row in dfSI.iterrows():
    clf = 0
    for p in range(0, len(serSI)):
        if row['DATA_TYPE'] == serSI.index[p]:
            ind = p
            arrl = arrlM[ind]
            for u in range(0, len(arrl)-1):
                if (row['DATA_RANGE'] > arrl[u]) and (row['DATA_RANGE'] <= arrl[u+1]):
                    clf = u + 1
                elif (row['DATA_RANGE'] > arrl[u+1]):
                    clf = len(arrl)            
    dfSI['RANGE_SI'] = clf

# %%
dfS.to_csv("dfS_tot.csv", sep=';')
dfSI.to_csv("dfSI_tot.csv", sep=';')

# %%
dfS.to_csv("dfS.csv", sep=';')
dfSI.to_csv("dfSI.csv", sep=';')
