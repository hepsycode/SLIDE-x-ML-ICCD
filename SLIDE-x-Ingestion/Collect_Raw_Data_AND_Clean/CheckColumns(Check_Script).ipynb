# %%
import pandas as pd
import numpy as np
import os
import sys
import ntpath

# %%
dfTot = pd.read_csv("TotalParameterMatrix.csv", sep=';')
del dfTot['Unnamed: 0']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-4a89487acf0e> in <module>
# ----> 1 dfTot = pd.read_csv("TotalParameterMatrix.csv", sep=';')
#       2 del dfTot['Unnamed: 0']
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     944             self.options["has_index_names"] = kwds["has_index_names"]
#     945
# --> 946         self._make_engine(self.engine)
#     947
#     948     def close(self):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1176     def _make_engine(self, engine="c"):
#    1177         if engine == "c":
# -> 1178             self._engine = CParserWrapper(self.f, **self.options)
#    1179         else:
#    1180             if engine == "python":
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    2006         kwds["usecols"] = self.usecols
#    2007
# -> 2008         self._reader = parsers.TextReader(src, **kwds)
#    2009         self.unnamed_cols = self._reader.unnamed_cols
#    2010
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'TotalParameterMatrix.csv'

# %%
col = list(dfTot.columns)
dataframe_collection = {}

for i in range(0,np.size(col)):
    a = np.where(pd.isna(dfTot[col[i]]))
    if not (np.size(a)==0):
        print(col[i])
        dfPar = dfTot.iloc[a][['DEVICE','FUNCTION','DATA_TYPE',col[i]]]
        dfPar.to_csv("ParMatrix"+col[i]+".csv", sep=';')
        dataframe_collection[col[i]] = dfPar
# Out:
# TimeToImplement
# FunctionCall
# PointerDereferencing
# CyclomaticComplexity
# CoverageEstimation
# SCALAR_INPUT
# RANGE_SCALAR_VALUES
# SCALAR_INDEX_INPUT
# RANGE_SCALAR_INDEX_VALUES
# ARRAY_INPUT
# RANGE_ARRAY_INPUT
# assemblyInstr
# clockCycles
# CC4CS

# %%
for key in dataframe_collection.keys():
    print("\n" +"="*40)
    print(key)
    print("-"*40)
    print(dataframe_collection[key])
# Out:
# ========================================
# TimeToImplement
# ----------------------------------------
#        DEVICE          FUNCTION DATA_TYPE  TimeToImplement
# 1000    Bambu     insertionsort     float              NaN
# 1001    Bambu     insertionsort     float              NaN
# 1002    Bambu     insertionsort     float              NaN
# 1003    Bambu     insertionsort     float              NaN
# 1004    Bambu     insertionsort     float              NaN
# ...       ...               ...       ...              ...
# 115179  Bambu  Banker_algorithm     float              NaN
# 115180  Bambu  Banker_algorithm     float              NaN
# 115181  Bambu  Banker_algorithm     float              NaN
# 115182  Bambu  Banker_algorithm     float              NaN
# 115183  Bambu  Banker_algorithm     float              NaN
#
# [27555 rows x 4 columns]
#
# ========================================
# FunctionCall
# ----------------------------------------
#       DEVICE       FUNCTION DATA_TYPE  FunctionCall
# 92091  Bambu  selectionsort    int8_t           NaN
# 92350  Bambu  selectionsort    int8_t           NaN
# 92400  Bambu  selectionsort    int8_t           NaN
# 92850  Bambu  selectionsort    int8_t           NaN
#
# ========================================
# PointerDereferencing
# ----------------------------------------
#        DEVICE       FUNCTION DATA_TYPE  PointerDereferencing
# 75945   Bambu   binarysearch     float                   NaN
# 75968   Bambu   binarysearch     float                   NaN
# 75974   Bambu   binarysearch     float                   NaN
# 75992   Bambu   binarysearch     float                   NaN
# 75996   Bambu   binarysearch     float                   NaN
# ...       ...            ...       ...                   ...
# 94018   Bambu  selectionsort   int16_t                   NaN
# 94032   Bambu  selectionsort   int16_t                   NaN
# 94083   Bambu  selectionsort   int16_t                   NaN
# 96933   Leon3  selectionsort    int8_t                   NaN
# 101134  Bambu            gcd    int8_t                   NaN
#
# [131 rows x 4 columns]
#
# ========================================
# CyclomaticComplexity
# ----------------------------------------
#        DEVICE       FUNCTION DATA_TYPE  CyclomaticComplexity
# 75945   Bambu   binarysearch     float                   NaN
# 75968   Bambu   binarysearch     float                   NaN
# 75974   Bambu   binarysearch     float                   NaN
# 75992   Bambu   binarysearch     float                   NaN
# 75996   Bambu   binarysearch     float                   NaN
# ...       ...            ...       ...                   ...
# 96539   Leon3  selectionsort    int8_t                   NaN
# 96570   Leon3  selectionsort    int8_t                   NaN
# 96779   Leon3  selectionsort    int8_t                   NaN
# 96933   Leon3  selectionsort    int8_t                   NaN
# 101134  Bambu            gcd    int8_t                   NaN
#
# [749 rows x 4 columns]
#
# ========================================
# CoverageEstimation
# ----------------------------------------
#        DEVICE       FUNCTION DATA_TYPE  CoverageEstimation
# 2017    Bambu  insertionsort    int8_t                 NaN
# 56698   Bambu     bubblesort   int32_t                 NaN
# 57308   Bambu     bubblesort     float                 NaN
# 57351   Bambu     bubblesort     float                 NaN
# 57461   Bambu     bubblesort     float                 NaN
# ...       ...            ...       ...                 ...
# 104923  Leon3            gcd    int8_t                 NaN
# 104941  Leon3            gcd    int8_t                 NaN
# 105008  Leon3            gcd    int8_t                 NaN
# 105021  Leon3            gcd    int8_t                 NaN
# 105149  Leon3            gcd    int8_t                 NaN
#
# [2369 rows x 4 columns]
#
# ========================================
# SCALAR_INPUT
# ----------------------------------------
#       DEVICE   FUNCTION DATA_TYPE  SCALAR_INPUT
# 46896  Bambu  mergesort  float_10           NaN
# 46897  Bambu  mergesort  float_10           NaN
# 46898  Bambu  mergesort  float_10           NaN
# 46899  Bambu  mergesort  float_10           NaN
# 46900  Bambu  mergesort  float_10           NaN
# 46901  Bambu  mergesort  float_10           NaN
# 46902  Bambu  mergesort  float_10           NaN
# 46903  Bambu  mergesort  float_10           NaN
# 46904  Bambu  mergesort  float_10           NaN
# 46905  Bambu  mergesort  float_10           NaN
# 69906  Bambu    kruskal  float_10           NaN
# 69907  Bambu    kruskal  float_10           NaN
# 69908  Bambu    kruskal  float_10           NaN
# 69909  Bambu    kruskal  float_10           NaN
# 69910  Bambu    kruskal  float_10           NaN
# 69911  Bambu    kruskal  float_10           NaN
# 69912  Bambu    kruskal  float_10           NaN
# 69913  Bambu    kruskal  float_10           NaN
# 69914  Bambu    kruskal  float_10           NaN
# 69915  Bambu    kruskal  float_10           NaN
#
# ========================================
# RANGE_SCALAR_VALUES
# ----------------------------------------
#       DEVICE   FUNCTION DATA_TYPE  RANGE_SCALAR_VALUES
# 46896  Bambu  mergesort  float_10                  NaN
# 46897  Bambu  mergesort  float_10                  NaN
# 46898  Bambu  mergesort  float_10                  NaN
# 46899  Bambu  mergesort  float_10                  NaN
# 46900  Bambu  mergesort  float_10                  NaN
# 46901  Bambu  mergesort  float_10                  NaN
# 46902  Bambu  mergesort  float_10                  NaN
# 46903  Bambu  mergesort  float_10                  NaN
# 46904  Bambu  mergesort  float_10                  NaN
# 46905  Bambu  mergesort  float_10                  NaN
# 69906  Bambu    kruskal  float_10                  NaN
# 69907  Bambu    kruskal  float_10                  NaN
# 69908  Bambu    kruskal  float_10                  NaN
# 69909  Bambu    kruskal  float_10                  NaN
# 69910  Bambu    kruskal  float_10                  NaN
# 69911  Bambu    kruskal  float_10                  NaN
# 69912  Bambu    kruskal  float_10                  NaN
# 69913  Bambu    kruskal  float_10                  NaN
# 69914  Bambu    kruskal  float_10                  NaN
# 69915  Bambu    kruskal  float_10                  NaN
#
# ========================================
# SCALAR_INDEX_INPUT
# ----------------------------------------
#       DEVICE   FUNCTION DATA_TYPE  SCALAR_INDEX_INPUT
# 46896  Bambu  mergesort  float_10                 NaN
# 46897  Bambu  mergesort  float_10                 NaN
# 46898  Bambu  mergesort  float_10                 NaN
# 46899  Bambu  mergesort  float_10                 NaN
# 46900  Bambu  mergesort  float_10                 NaN
# 46901  Bambu  mergesort  float_10                 NaN
# 46902  Bambu  mergesort  float_10                 NaN
# 46903  Bambu  mergesort  float_10                 NaN
# 46904  Bambu  mergesort  float_10                 NaN
# 46905  Bambu  mergesort  float_10                 NaN
# 69906  Bambu    kruskal  float_10                 NaN
# 69907  Bambu    kruskal  float_10                 NaN
# 69908  Bambu    kruskal  float_10                 NaN
# 69909  Bambu    kruskal  float_10                 NaN
# 69910  Bambu    kruskal  float_10                 NaN
# 69911  Bambu    kruskal  float_10                 NaN
# 69912  Bambu    kruskal  float_10                 NaN
# 69913  Bambu    kruskal  float_10                 NaN
# 69914  Bambu    kruskal  float_10                 NaN
# 69915  Bambu    kruskal  float_10                 NaN
#
# ========================================
# RANGE_SCALAR_INDEX_VALUES
# ----------------------------------------
#       DEVICE   FUNCTION DATA_TYPE  RANGE_SCALAR_INDEX_VALUES
# 46896  Bambu  mergesort  float_10                        NaN
# 46897  Bambu  mergesort  float_10                        NaN
# 46898  Bambu  mergesort  float_10                        NaN
# 46899  Bambu  mergesort  float_10                        NaN
# 46900  Bambu  mergesort  float_10                        NaN
# 46901  Bambu  mergesort  float_10                        NaN
# 46902  Bambu  mergesort  float_10                        NaN
# 46903  Bambu  mergesort  float_10                        NaN
# 46904  Bambu  mergesort  float_10                        NaN
# 46905  Bambu  mergesort  float_10                        NaN
# 69906  Bambu    kruskal  float_10                        NaN
# 69907  Bambu    kruskal  float_10                        NaN
# 69908  Bambu    kruskal  float_10                        NaN
# 69909  Bambu    kruskal  float_10                        NaN
# 69910  Bambu    kruskal  float_10                        NaN
# 69911  Bambu    kruskal  float_10                        NaN
# 69912  Bambu    kruskal  float_10                        NaN
# 69913  Bambu    kruskal  float_10                        NaN
# 69914  Bambu    kruskal  float_10                        NaN
# 69915  Bambu    kruskal  float_10                        NaN
#
# ========================================
# ARRAY_INPUT
# ----------------------------------------
#       DEVICE   FUNCTION DATA_TYPE  ARRAY_INPUT
# 46896  Bambu  mergesort  float_10          NaN
# 46897  Bambu  mergesort  float_10          NaN
# 46898  Bambu  mergesort  float_10          NaN
# 46899  Bambu  mergesort  float_10          NaN
# 46900  Bambu  mergesort  float_10          NaN
# 46901  Bambu  mergesort  float_10          NaN
# 46902  Bambu  mergesort  float_10          NaN
# 46903  Bambu  mergesort  float_10          NaN
# 46904  Bambu  mergesort  float_10          NaN
# 46905  Bambu  mergesort  float_10          NaN
# 69906  Bambu    kruskal  float_10          NaN
# 69907  Bambu    kruskal  float_10          NaN
# 69908  Bambu    kruskal  float_10          NaN
# 69909  Bambu    kruskal  float_10          NaN
# 69910  Bambu    kruskal  float_10          NaN
# 69911  Bambu    kruskal  float_10          NaN
# 69912  Bambu    kruskal  float_10          NaN
# 69913  Bambu    kruskal  float_10          NaN
# 69914  Bambu    kruskal  float_10          NaN
# 69915  Bambu    kruskal  float_10          NaN
#
# ========================================
# RANGE_ARRAY_INPUT
# ----------------------------------------
#       DEVICE   FUNCTION DATA_TYPE  RANGE_ARRAY_INPUT
# 46896  Bambu  mergesort  float_10                NaN
# 46897  Bambu  mergesort  float_10                NaN
# 46898  Bambu  mergesort  float_10                NaN
# 46899  Bambu  mergesort  float_10                NaN
# 46900  Bambu  mergesort  float_10                NaN
# 46901  Bambu  mergesort  float_10                NaN
# 46902  Bambu  mergesort  float_10                NaN
# 46903  Bambu  mergesort  float_10                NaN
# 46904  Bambu  mergesort  float_10                NaN
# 46905  Bambu  mergesort  float_10                NaN
# 69906  Bambu    kruskal  float_10                NaN
# 69907  Bambu    kruskal  float_10                NaN
# 69908  Bambu    kruskal  float_10                NaN
# 69909  Bambu    kruskal  float_10                NaN
# 69910  Bambu    kruskal  float_10                NaN
# 69911  Bambu    kruskal  float_10                NaN
# 69912  Bambu    kruskal  float_10                NaN
# 69913  Bambu    kruskal  float_10                NaN
# 69914  Bambu    kruskal  float_10                NaN
# 69915  Bambu    kruskal  float_10                NaN
#
# ========================================
# assemblyInstr
# ----------------------------------------
#        DEVICE          FUNCTION DATA_TYPE  assemblyInstr
# 0       Bambu     insertionsort   int32_t            NaN
# 1       Bambu     insertionsort   int32_t            NaN
# 2       Bambu     insertionsort   int32_t            NaN
# 3       Bambu     insertionsort   int32_t            NaN
# 4       Bambu     insertionsort   int32_t            NaN
# ...       ...               ...       ...            ...
# 117227  Bambu  Banker_algorithm   int16_t            NaN
# 117228  Bambu  Banker_algorithm   int16_t            NaN
# 117229  Bambu  Banker_algorithm   int16_t            NaN
# 117230  Bambu  Banker_algorithm   int16_t            NaN
# 117231  Bambu  Banker_algorithm   int16_t            NaN
#
# [59320 rows x 4 columns]
#
# ========================================
# clockCycles
# ----------------------------------------
#        DEVICE       FUNCTION DATA_TYPE  clockCycles
# 106914  Bambu     matrix_mul     float          NaN
# 106915  Bambu     matrix_mul     float          NaN
# 106922  Bambu     matrix_mul     float          NaN
# 106925  Bambu     matrix_mul     float          NaN
# 106928  Bambu     matrix_mul     float          NaN
# ...       ...            ...       ...          ...
# 112754  Bambu  floydwarshall   int16_t          NaN
# 112824  Bambu  floydwarshall   int16_t          NaN
# 112933  Bambu  floydwarshall   int16_t          NaN
# 113012  Bambu  floydwarshall   int16_t          NaN
# 113045  Bambu  floydwarshall   int16_t          NaN
#
# [424 rows x 4 columns]
#
# ========================================
# CC4CS
# ----------------------------------------
#        DEVICE       FUNCTION DATA_TYPE  CC4CS
# 106914  Bambu     matrix_mul     float    NaN
# 106915  Bambu     matrix_mul     float    NaN
# 106922  Bambu     matrix_mul     float    NaN
# 106925  Bambu     matrix_mul     float    NaN
# 106928  Bambu     matrix_mul     float    NaN
# ...       ...            ...       ...    ...
# 112754  Bambu  floydwarshall   int16_t    NaN
# 112824  Bambu  floydwarshall   int16_t    NaN
# 112933  Bambu  floydwarshall   int16_t    NaN
# 113012  Bambu  floydwarshall   int16_t    NaN
# 113045  Bambu  floydwarshall   int16_t    NaN
#
# [424 rows x 4 columns]
