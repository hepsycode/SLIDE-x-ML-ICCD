# %%
##### Feature Importance Code

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import io
import time

from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, log_loss, accuracy_score, f1_score
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
def feature_importances_histo(clf, file_name_path, file_name_generalScore, X_train, y_train=None,
                              top_n=10, figsize=(8, 8), print_table=False, title="Feature Importances"):
    __name__ = "feature_importances_histo"

    # try:
    if not hasattr(clf, 'feature_importances_'):
        clf.fit(X_train.values, y_train.values.ravel())

        if not hasattr(clf, 'feature_importances_'):
            raise AttributeError("{} does not have feature_importances_ attribute".
                                 format(clf.__class__.__name__))

    feat_imp = pd.DataFrame({title: clf.feature_importances_})
    feat_imp['feature'] = X_train.columns
    dfAllResults['feature'] = X_train.columns
    dfAllResults[title] = clf.feature_importances_
    feat_imp = feat_imp.iloc[:top_n]
    feat_imp.sort_values(by='feature', ascending=False, inplace=True)
    feat_imp = feat_imp.set_index('feature', drop=True)

    print("\n================  Feature Importance  ==============")
    print(title)
    print("____________________________________________________")
    print(feat_imp)
    print("----------------------------------------------------")

    feat_imp.plot.barh(title=title, figsize=figsize)
    plt.xlabel('Feature Importance Score')
    plt.rcParams.update({'font.size': 5})
    # plt.show()
    # plt.savefig(os.path.join(file_name_path, title + file_name_generalScore))

    if print_table:
        from IPython.display import display
        print("Top {} features in descending order of importance".format(top_n))
        display(feat_imp.sort_values(by='feature', ascending=False))

    return feat_imp

# %%
ESTIMATORS = 250

#from google.colab import files
#uploaded = files.upload()


# import required module
import os

# assign directory
directory = 'Dataset\csv\Train'
filename = 'Artix-7.csv'

# iterate over files in that directory
#for filename in os.listdir(directory): # INDENT
f = os.path.join(directory, filename)
fileTrainName = f.split('\\')
# checking if it is a file
if os.path.isfile(f):
    fileTrainNameNoFormat = fileTrainName[3].split('.')

    print("\n|------------------------------------|")
    print('\n' + fileTrainNameNoFormat[0] + '\n')
    print("|------------------------------------|\n")

df = pd.read_csv(f, encoding = 'utf8', sep=',')
# del df['Unnamed: 0']

listHeader = list(df.columns.values)
print(listHeader)
print(listHeader[7:12])
print(listHeader[49])
y = df[["DSP", "BRAM", "Flip_Flop", "Area", "min_Slack", "Max_Freq","clockCycles"]]
print(y)
X = df.drop(['ID_VAL', 'DEVICE', 'BOARD', 'FUNCTION', 'DATA_TYPE', 'DSP', 'BRAM', 'Flip_Flop', 'Area', 'min_Slack', 'Max_Freq', 'Time', 'Energy', 'assemblyInstr', 'clockCycles', 'CC4CS'], axis=1)
print(X)

#temporary dataframe for results
dfAllResults = pd.DataFrame()

# X = df[listHeader].astype(float)

for y_series_name, y_series in y.items():

    X_train, X_test, y_train, y_test = train_test_split(X, y_series, test_size=0.20, shuffle=False)

    ## Main Function

    clfs = [ExtraTreesRegressor(),
            GradientBoostingRegressor(learning_rate=0.1, n_estimators=ESTIMATORS),
            AdaBoostRegressor(learning_rate=0.1),
            RandomForestRegressor()
            ]

    print("\n|------------------------------------|")
    print('\n' + y_series_name + '\n')
    print("|------------------------------------|\n")

    file_name_path = 'FeatureImportRes\\generalScore\\'
    file_name_generalScore = fileTrainNameNoFormat[0] + y_series_name + '.png'

    for clf in clfs:
        try:
            _ = feature_importances_histo(clf, file_name_path, file_name_generalScore, X_train, y_train, top_n=X_train.shape[1], title=clf.__class__.__name__)
        except AttributeError as e:
            print(e)

    dfAllResults.set_index(['feature'], inplace=True)

    file_name_path = 'FeatureImportRes\\generalScore\\'
    file_name_generalScore = fileTrainNameNoFormat[0] + y_series_name + '.csv'
    dfAllResults.to_csv(os.path.join(file_name_path, file_name_generalScore), sep=',', encoding='utf-8', index=False)
    dfAllResults['sum'] = dfAllResults[dfAllResults.columns].sum(axis=1)
    dfAllResults['avg'] = dfAllResults['sum']/(len(dfAllResults.columns) - 1)
    file_name_path = 'FeatureImportRes\\allCLFscore\\'
    file_name = fileTrainNameNoFormat[0] + y_series_name + '.csv'
    dfAllResults.to_csv(os.path.join(file_name_path, file_name), sep='\t', encoding='utf-8')
    #files.download(file_name)

    print(dfAllResults)

    dfavg = dfAllResults[['avg']]
    file_name_path = 'FeatureImportRes\\scoreMean\\'
    file_name = fileTrainNameNoFormat[0] + y_series_name + '.csv'
    dfavg.to_csv(os.path.join(file_name_path, file_name), sep='\t', encoding='utf-8')
    #files.download(file_name)

    dfavg.plot.barh(title='Feature Importance Mean Score',logx=True, figsize=(8, 8))
    plt.xlabel('Feature Importance Mean Score')
    plt.xscale('log')
    plt.axvline(x=0.001)
    plt.rcParams.update({'font.size': 5})
    # plt.show()
    file_name_png = 'Mean' + fileTrainNameNoFormat[0] + y_series_name + '.png'
    # plt.savefig(os.path.join(file_name_path, file_name_png), format='png')

    print("\n=============   Feature Importance Mean Score   =============")
    print(dfavg)
    dfpruned = dfavg[~(dfavg['avg'] < 0.05)]
    print("\n=============   Feature Pruned by Score   =============")
    print(dfpruned)
    file_name_dataset_train_test_pruned = 'DatasetReduced/Train_Test_Pruned_' + fileTrainNameNoFormat[0] + '_' + y_series_name + '.csv' 
    dfpruned.to_csv(file_name_dataset_train_test_pruned, encoding='utf-8')
    
    df_pruned = pd.read_csv(file_name_dataset_train_test_pruned, encoding='utf-8')
    columnPruned = df_pruned[df_pruned.columns[0]].to_numpy()
    list_Pruned = columnPruned.tolist()
    print(list_Pruned)

    dfavg.plot.barh(title='Feature Importance Mean Score',logx=True, figsize=(8, 8))
    plt.xscale('log')
    plt.axvline(x=0.001, color='r', linestyle='--')
    plt.rcParams.update({'font.size': 5})
    # plt.show()
    file_name_png = 'MeanRed' + fileTrainNameNoFormat[0] + y_series_name + '.png'
    # plt.savefig(os.path.join(file_name_path, file_name_png), format='png')

    # remove features from df and save dataset file
    file_name_dataset_train = 'DatasetReduced/Train_' + fileTrainNameNoFormat[0] + '_' + y_series_name + '.csv' 
    df_X_train = pd.DataFrame(X_train)
    # df_X_train = df_X_train_1.drop(list_Pruned)
    df_X_train.loc[~df_X_train.columns.str.contains('|'.join(list_Pruned))]
    df_y_train = pd.DataFrame(y_train)
    df_final_train = pd.concat([df_X_train, df_y_train], axis=1)
    df_final_train.to_csv(file_name_dataset_train)
    
    file_name_dataset_test = 'DatasetReduced/Test_' + fileTrainNameNoFormat[0] + '_' + y_series_name + '.csv'
    df_X_test = pd.DataFrame(X_test)
    # df_X_test = df_X_test_1.drop(list_Pruned)
    df_X_test.loc[~df_X_test.columns.str.contains('|'.join(list_Pruned))]
    df_y_test = pd.DataFrame(y_test)
    df_final_test = pd.concat([df_X_test, df_y_test], axis=1)
    df_final_test.to_csv(file_name_dataset_test)
    
    if os.path.exists(file_name_dataset_train_test_pruned):
        os.remove(file_name_dataset_train_test_pruned)
    else:
        print(file_name_dataset_train_test_pruned)
# Out:
# |------------------------------------|
#
# Artix-7
#
# |------------------------------------|
#
# ['Column1', 'DEVICE', 'BOARD', 'FUNCTION', 'DATA_TYPE', 'ID_VAL', 'DSP', 'BRAM', 'Flip_Flop', 'Area', 'min_Slack', 'Max_Freq', 'Time', 'Energy', 'BugsDelivered', 'DifficultyLevel', 'DistinctOperands', 'DistinctOperators', 'Effort', 'ProgramLength', 'ProgramLevel', 'ProgramVolume', 'TimeToImplement', 'TotalOperators', 'Total_Operands', 'VocabularySize', 'Sloc', 'DecisionPoint', 'GlobalVariables', 'If', 'Loop', 'Goto', 'Assignment', 'ExitPoint', 'Function.1', 'FunctionCall', 'PointerDereferencing', 'CyclomaticComplexity', 'SyntacticallyReachableFunctions', 'SemanticallyReachedFunctions', 'CoverageEstimation', 'SCALAR_INPUT', 'RANGE_SCALAR_VALUES', 'SCALAR_INDEX_INPUT', 'RANGE_SCALAR_INDEX_VALUES', 'ARRAY_INPUT', 'RANGE_ARRAY_INPUT', 'cInstr', 'assemblyInstr', 'clockCycles', 'CC4CS', 'Bugs_Delivered', 'SS_VAL_1', 'SV_VAL_1', 'SV_VAL_2', 'V_VAL_1', 'V_VAL_2', 'V_VAL_3', 'V_VAL_4', 'V_VAL_5', 'V_VAL_6', 'V_VAL_7', 'V_VAL_8', 'V_VAL_9', 'V_VAL_10', 'V_VAL_11', 'V_VAL_12', 'V_VAL_13', 'V_VAL_14', 'V_VAL_15', 'V_VAL_16', 'V_VAL_17', 'V_VAL_18', 'V_VAL_19', 'V_VAL_20', 'V_VAL_21', 'V_VAL_22', 'V_VAL_23', 'V_VAL_24', 'V_VAL_25', 'V_VAL_26', 'V_VAL_27', 'V_VAL_28', 'M_VAL_1', 'M_VAL_2', 'M_VAL_3', 'M_VAL_4', 'M_VAL_5', 'M_VAL_6', 'M_VAL_7', 'M_VAL_8', 'M_VAL_9', 'M_VAL_10', 'M_VAL_11', 'M_VAL_12', 'M_VAL_13', 'M_VAL_14', 'M_VAL_15', 'M_VAL_16', 'M_VAL_17', 'M_VAL_18', 'M_VAL_19', 'M_VAL_20', 'M_VAL_21', 'M_VAL_22', 'M_VAL_23', 'M_VAL_24', 'M_VAL_25', 'M_VAL_26', 'M_VAL_27', 'M_VAL_28', 'M_VAL_29', 'M_VAL_30', 'M_VAL_31', 'M_VAL_32']
# ['BRAM', 'Flip_Flop', 'Area', 'min_Slack', 'Max_Freq']
# clockCycles
#       DSP  BRAM  Flip_Flop   Area     min_Slack    Max_Freq  clockCycles
# 0       0    16        694  17067  1.110220e-16  290.782204          391
# 1       0     8        967  17200  1.110220e-16  290.782204         3495
# 2       0     8       1089  17240  1.110220e-16  290.782204        26250
# 3       0    16        709  17083  1.110220e-16  290.782204          504
# 4       0    16        694  17067  1.110220e-16  290.782204          390
# ...   ...   ...        ...    ...           ...         ...          ...
# 1395    4     8        612   2805  1.887380e-15  200.104054          506
# 1396    4     8        612   2805  1.887380e-15  200.104054          710
# 1397    4     8        612   2805  1.887380e-15  200.104054          124
# 1398    4     8        612   2805  1.887380e-15  200.104054          221
# 1399    4     8        612   2805  1.887380e-15  200.104054         1157
#
# [1400 rows x 7 columns]
#       Column1  BugsDelivered  DifficultyLevel  DistinctOperands  \
# 0        6500       2.129710            79.66               116
# 1        6501       2.859837            68.40               179
# 2        6502       6.278477           121.00               231
# 3        6503       2.265920            74.00               132
# 4        6504       2.139200            78.31               118
# ...       ...            ...              ...               ...
# 1395     7395       0.526000            42.50                28
# 1396     7396       0.558080            39.92                32
# 1397     7397       0.460390            53.42                19
# 1398     7398       0.476353            48.52                22
# 1399     7399       0.606710            37.84                37
#
#       DistinctOperators      Effort  ProgramLength  ProgramLevel  \
# 0                    66   508927.51            851          0.01
# 1                    66   586809.43           1081          0.01
# 2                    66  2279087.48           2293          0.01
# 3                    66   503034.00            891          0.01
# 4                    66   502530.58            853          0.01
# ...                 ...         ...            ...           ...
# 1395                 35    67065.08            264          0.02
# 1396                 35    66838.82            276          0.03
# 1397                 35    73783.72            240          0.02
# 1398                 35    69341.79            245          0.02
# 1399                 35    68869.70            295          0.03
#
#       ProgramVolume  TimeToImplement  ...  M_VAL_23  M_VAL_24  M_VAL_25  \
# 0           6389.13         28273.75  ...         0         0         0
# 1           8579.51         32600.52  ...         3         7         5
# 2          18835.43        126615.97  ...         0        27         4
# 3           6797.76         27946.33  ...         0         0         0
# 4           6417.60         27918.37  ...         0         0         0
# ...             ...              ...  ...       ...       ...       ...
# 1395        1578.00          3725.84  ...         0         0         0
# 1396        1674.24          3713.27  ...         0         0         0
# 1397        1381.17          4099.10  ...         0         0         0
# 1398        1429.06          3852.32  ...         0         0         0
# 1399        1820.13          3826.09  ...         0         0         0
#
#       M_VAL_26  M_VAL_27  M_VAL_28  M_VAL_29  M_VAL_30  M_VAL_31  M_VAL_32
# 0            0         0         0         0         0         0         0
# 1            5         5         5         2         2         0         0
# 2           36        28         4         0        56         0        26
# 3            0         0         0         0         0         0         0
# 4            0         0         0         0         0         0         0
# ...        ...       ...       ...       ...       ...       ...       ...
# 1395         0         0         0         0         0         0         0
# 1396         0         0         0         0         0         0         0
# 1397         0         0         0         0         0         0         0
# 1398         0         0         0         0         0         0         0
# 1399         0         0         0         0         0         0         0
#
# [1400 rows x 99 columns]
#
# |------------------------------------|
#
# DSP
#
# |------------------------------------|
#
#
# ================  Feature Importance  ==============
# ExtraTreesRegressor
# ____________________________________________________
#                 ExtraTreesRegressor
# feature
# cInstr                     0.009923
# VocabularySize             0.013499
# V_VAL_9                    0.004205
# V_VAL_8                    0.006125
# V_VAL_7                    0.003112
# ...                             ...
# Column1                    0.004736
# Bugs_Delivered             0.013864
# BugsDelivered              0.027060
# Assignment                 0.010652
# ARRAY_INPUT                0.251457
#
# [99 rows x 1 columns]
# ----------------------------------------------------
#
# ================  Feature Importance  ==============
# GradientBoostingRegressor
# ____________________________________________________
#                 GradientBoostingRegressor
# feature
# cInstr                       3.710064e-02
# VocabularySize               5.893789e-05
# V_VAL_9                      4.239965e-03
# V_VAL_8                      1.150121e-03
# V_VAL_7                      1.089125e-04
# ...                                   ...
# Column1                      2.346694e-05
# Bugs_Delivered               1.016098e-03
# BugsDelivered                5.222810e-03
# Assignment                   7.820880e-07
# ARRAY_INPUT                  2.570079e-01
#
# [99 rows x 1 columns]
# ----------------------------------------------------
#
# ================  Feature Importance  ==============
# AdaBoostRegressor
# ____________________________________________________
#                 AdaBoostRegressor
# feature
# cInstr                   0.024272
# VocabularySize           0.000000
# V_VAL_9                  0.004298
# V_VAL_8                  0.003040
# V_VAL_7                  0.002700
# ...                           ...
# Column1                  0.002612
# Bugs_Delivered           0.003522
# BugsDelivered            0.008938
# Assignment               0.000000
# ARRAY_INPUT              0.325446
#
# [99 rows x 1 columns]
# ----------------------------------------------------
# ================  Feature Importance  ==============
# RandomForestRegressor
# ____________________________________________________
#                 RandomForestRegressor
# feature
# cInstr                       0.017371
# VocabularySize               0.001022
# V_VAL_9                      0.003559
# V_VAL_8                      0.005890
# V_VAL_7                      0.010238
# ...                               ...
# Column1                      0.012846
# Bugs_Delivered               0.001602
# BugsDelivered                0.004196
# Assignment                   0.000000
# ARRAY_INPUT                  0.293472
#
# [99 rows x 1 columns]
# ----------------------------------------------------
#                    ExtraTreesRegressor  GradientBoostingRegressor  \
# feature
# Column1                       0.004736                   0.000023
# BugsDelivered                 0.027060                   0.005223
# DifficultyLevel               0.018015                   0.041301
# DistinctOperands              0.010013                   0.000037
# DistinctOperators             0.000000                   0.000106
# ...                                ...                        ...
# M_VAL_28                      0.008167                   0.003022
# M_VAL_29                      0.003241                   0.004776
# M_VAL_30                      0.006978                   0.000485
# M_VAL_31                      0.008649                   0.019167
# M_VAL_32                      0.000276                   0.000495
#
#                    AdaBoostRegressor  RandomForestRegressor       sum  \
# feature
# Column1                     0.002612               0.012846  0.020217
# BugsDelivered               0.008938               0.004196  0.045416
# DifficultyLevel             0.009918               0.022642  0.091877
# DistinctOperands            0.000000               0.001301  0.011350
# DistinctOperators           0.000000               0.000000  0.000106
# ...                              ...                    ...       ...
# M_VAL_28                    0.011146               0.008006  0.030341
# M_VAL_29                    0.000000               0.007235  0.015253
# M_VAL_30                    0.000000               0.002361  0.009824
# M_VAL_31                    0.000000               0.003482  0.031299
# M_VAL_32                    0.000316               0.003167  0.004254
#
#                         avg
# feature
# Column1            0.005054
# BugsDelivered      0.011354
# DifficultyLevel    0.022969
# DistinctOperands   0.002838
# DistinctOperators  0.000027
# ...                     ...
# M_VAL_28           0.007585
# M_VAL_29           0.003813
# M_VAL_30           0.002456
# M_VAL_31           0.007825
# M_VAL_32           0.001064
#
# [99 rows x 6 columns]
#
# =============   Feature Importance Mean Score   =============
#                         avg
# feature
# Column1            0.005054
# BugsDelivered      0.011354
# DifficultyLevel    0.022969
# DistinctOperands   0.002838
# DistinctOperators  0.000027
# ...                     ...
# M_VAL_28           0.007585
# M_VAL_29           0.003813
# M_VAL_30           0.002456
# M_VAL_31           0.007825
# M_VAL_32           0.001064
#
# [99 rows x 1 columns]
#
# =============   Feature Pruned by Score   =============
#                            avg
# feature
# PointerDereferencing  0.242482
# ARRAY_INPUT           0.281846
# ['PointerDereferencing', 'ARRAY_INPUT']
#
# |------------------------------------|
#
# BRAM
#
# |------------------------------------|
#
#
# ================  Feature Importance  ==============
# ExtraTreesRegressor
# ____________________________________________________
#                 ExtraTreesRegressor
# feature
# cInstr                     0.010277
# VocabularySize             0.030958
# V_VAL_9                    0.000000
# V_VAL_8                    0.000000
# V_VAL_7                    0.000000
# ...                             ...
# Column1                    0.166295
# Bugs_Delivered             0.021891
# BugsDelivered              0.012778
# Assignment                 0.053423
# ARRAY_INPUT                0.002741
#
# [99 rows x 1 columns]
# ----------------------------------------------------
#
# ================  Feature Importance  ==============
# GradientBoostingRegressor
# ____________________________________________________
#                 GradientBoostingRegressor
# feature
# cInstr                           0.009249
# VocabularySize                   0.032472
# V_VAL_9                          0.000000
# V_VAL_8                          0.000000
# V_VAL_7                          0.000000
# ...                                   ...
# Column1                          0.596969
# Bugs_Delivered                   0.034231
# BugsDelivered                    0.015820
# Assignment                       0.022833
# ARRAY_INPUT                      0.000019
#
# [99 rows x 1 columns]
# ----------------------------------------------------
#
# ================  Feature Importance  ==============
# AdaBoostRegressor
# ____________________________________________________
#                 AdaBoostRegressor
# feature
# cInstr                   0.008896
# VocabularySize           0.019719
# V_VAL_9                  0.000000
# V_VAL_8                  0.000000
# V_VAL_7                  0.000000
# ...                           ...
# Column1                  0.276635
# Bugs_Delivered           0.042588
# BugsDelivered            0.035412
# Assignment               0.000693
# ARRAY_INPUT              0.000000
#
# [99 rows x 1 columns]
# ----------------------------------------------------
#
# ================  Feature Importance  ==============
# RandomForestRegressor
# ____________________________________________________
#                 RandomForestRegressor
# feature
# cInstr                       0.010762
# VocabularySize               0.009844
# V_VAL_9                      0.000000
# V_VAL_8                      0.000034
# V_VAL_7                      0.000045
# ...                               ...
# Column1                      0.685372
# Bugs_Delivered               0.018248
# BugsDelivered                0.015341
# Assignment                   0.000006
# ARRAY_INPUT                  0.000093
#
# [99 rows x 1 columns]
# ----------------------------------------------------
#                    ExtraTreesRegressor  GradientBoostingRegressor  \
# feature
# Column1                       0.166295                   0.596969
# BugsDelivered                 0.012778                   0.015820
# DifficultyLevel               0.005755                   0.020174
# DistinctOperands              0.062490                   0.011533
# DistinctOperators             0.008474                   0.004564
# ...                                ...                        ...
# M_VAL_28                      0.001132                   0.000006
# M_VAL_29                      0.001352                   0.000008
# M_VAL_30                      0.001932                   0.000073
# M_VAL_31                      0.000207                   0.000134
# M_VAL_32                      0.001718                   0.000054
#
#                    AdaBoostRegressor  RandomForestRegressor       sum  \
# feature
# Column1                     0.276635               0.685372  1.750542
# BugsDelivered               0.035412               0.015341  0.136121
# DifficultyLevel             0.039143               0.015480  0.195398
# DistinctOperands            0.173548               0.007256  0.269015
# DistinctOperators           0.000000               0.000504  0.013675
# ...                              ...                    ...       ...
# M_VAL_28                    0.000000               0.001838  0.040901
# M_VAL_29                    0.000000               0.000383  0.020809
# M_VAL_30                    0.000000               0.001332  0.015617
# M_VAL_31                    0.000000               0.000402  0.039866
# M_VAL_32                    0.000000               0.001773  0.008864
#
#                         avg
# feature
# Column1            0.350108
# BugsDelivered      0.027224
# DifficultyLevel    0.039080
# DistinctOperands   0.053803
# DistinctOperators  0.002735
# ...                     ...
# M_VAL_28           0.008180
# M_VAL_29           0.004162
# M_VAL_30           0.003123
# M_VAL_31           0.007973
# M_VAL_32           0.001773
#
# [99 rows x 6 columns]
# =============   Feature Importance Mean Score   =============
#                         avg
# feature
# Column1            0.350108
# BugsDelivered      0.027224
# DifficultyLevel    0.039080
# DistinctOperands   0.053803
# DistinctOperators  0.002735
# ...                     ...
# M_VAL_28           0.008180
# M_VAL_29           0.004162
# M_VAL_30           0.003123
# M_VAL_31           0.007973
# M_VAL_32           0.001773
#
# [99 rows x 1 columns]
#
# =============   Feature Pruned by Score   =============
#                            avg
# feature
# Column1               0.350108
# DistinctOperands      0.053803
# Goto                  0.051253
# PointerDereferencing  0.257047
# ARRAY_INPUT           0.282417
# ['Column1', 'DistinctOperands', 'Goto', 'PointerDereferencing', 'ARRAY_INPUT']
#
# |------------------------------------|
#
# Flip_Flop
#
# |------------------------------------|
#
#
# ================  Feature Importance  ==============
# ExtraTreesRegressor
# ____________________________________________________
#                 ExtraTreesRegressor
# feature
# cInstr                     0.001841
# VocabularySize             0.006266
# V_VAL_9                    0.000113
# V_VAL_8                    0.001449
# V_VAL_7                    0.000178
# ...                             ...
# Column1                    0.013843
# Bugs_Delivered             0.003284
# BugsDelivered              0.002569
# Assignment                 0.006749
# ARRAY_INPUT                0.000121
#
# [99 rows x 1 columns]
# ----------------------------------------------------
#
# ================  Feature Importance  ==============
# GradientBoostingRegressor
# ____________________________________________________
#                 GradientBoostingRegressor
# feature
# cInstr                           0.007058
# VocabularySize                   0.012659
# V_VAL_9                          0.000078
# V_VAL_8                          0.000257
# V_VAL_7                          0.000168
# ...                                   ...
# Column1                          0.125593
# Bugs_Delivered                   0.000352
# BugsDelivered                    0.000766
# Assignment                       0.003795
# ARRAY_INPUT                      0.000157
#
# [99 rows x 1 columns]
# ----------------------------------------------------
#
# ================  Feature Importance  ==============
# AdaBoostRegressor
# ____________________________________________________
#                 AdaBoostRegressor
# feature
# cInstr                   0.013597
# VocabularySize           0.006099
# V_VAL_9                  0.000987
# V_VAL_8                  0.000000
# V_VAL_7                  0.000578
# ...                           ...
# Column1                  0.049611
# Bugs_Delivered           0.001424
# BugsDelivered            0.000225
# Assignment               0.000000
# ARRAY_INPUT              0.000000
#
# [99 rows x 1 columns]
# ----------------------------------------------------
#
# ================  Feature Importance  ==============
# RandomForestRegressor
# ____________________________________________________
#                 RandomForestRegressor
# feature
# cInstr                       0.007617
# VocabularySize               0.023224
# V_VAL_9                      0.000121
# V_VAL_8                      0.001015
# V_VAL_7                      0.000283
# ...                               ...
# Column1                      0.146231
# Bugs_Delivered               0.007174
# BugsDelivered                0.006261
# Assignment                   0.000138
# ARRAY_INPUT                  0.000011
#
# [99 rows x 1 columns]
# ----------------------------------------------------
#                    ExtraTreesRegressor  GradientBoostingRegressor  \
# feature
# Column1                       0.013843                   0.125593
# BugsDelivered                 0.002569                   0.000766
# DifficultyLevel               0.002276                   0.004651
# DistinctOperands              0.008084                   0.016090
# DistinctOperators             0.003463                   0.000200
# ...                                ...                        ...
# M_VAL_28                      0.000223                   0.000255
# M_VAL_29                      0.000218                   0.000107
# M_VAL_30                      0.002076                   0.000104
# M_VAL_31                      0.000106                   0.000012
# M_VAL_32                      0.001682                   0.000065
#
#                    AdaBoostRegressor  RandomForestRegressor       sum  \
# feature
# Column1                     0.049611               0.146231  2.435928
# BugsDelivered               0.000225               0.006261  0.173166
# DifficultyLevel             0.002369               0.003775  0.247548
# DistinctOperands            0.001675               0.010003  0.358670
# DistinctOperators           0.000000               0.000136  0.020208
# ...                              ...                    ...       ...
# M_VAL_28                    0.000447               0.000261  0.050268
# M_VAL_29                    0.000000               0.000129  0.025425
# M_VAL_30                    0.000000               0.000308  0.021228
# M_VAL_31                    0.000000               0.000070  0.048027
# M_VAL_32                    0.000000               0.000237  0.012620
#
#                         avg
# feature
# Column1            0.487186
# BugsDelivered      0.034633
# DifficultyLevel    0.049510
# DistinctOperands   0.071734
# DistinctOperators  0.004042
# ...                     ...
# M_VAL_28           0.010054
# M_VAL_29           0.005085
# M_VAL_30           0.004246
# M_VAL_31           0.009605
# M_VAL_32           0.002524
#
# [99 rows x 6 columns]
#
# =============   Feature Importance Mean Score   =============
#                         avg
# feature
# Column1            0.487186
# BugsDelivered      0.034633
# DifficultyLevel    0.049510
# DistinctOperands   0.071734
# DistinctOperators  0.004042
# ...                     ...
# M_VAL_28           0.010054
# M_VAL_29           0.005085
# M_VAL_30           0.004246
# M_VAL_31           0.009605
# M_VAL_32           0.002524
#
# [99 rows x 1 columns]
#
# =============   Feature Pruned by Score   =============
#                                       avg
# feature
# Column1                          0.487186
# DistinctOperands                 0.071734
# DecisionPoint                    0.120640
# If                               0.102252
# Goto                             0.068257
# PointerDereferencing             0.308896
# CyclomaticComplexity             0.205085
# SyntacticallyReachableFunctions  0.055194
# ARRAY_INPUT                      0.338958
# ['Column1', 'DistinctOperands', 'DecisionPoint', 'If', 'Goto', 'PointerDereferencing', 'CyclomaticComplexity', 'SyntacticallyReachableFunctions', 'ARRAY_INPUT']
#
# |------------------------------------|
#
# Area
#
# |------------------------------------|
#
#
# ================  Feature Importance  ==============
# ExtraTreesRegressor
# ____________________________________________________
#                 ExtraTreesRegressor
# feature
# cInstr                 1.881415e-04
# VocabularySize         1.162514e-04
# V_VAL_9                1.030762e-05
# V_VAL_8                8.001294e-07
# V_VAL_7                1.099514e-06
# ...                             ...
# Column1                2.362029e-02
# Bugs_Delivered         6.893758e-05
# BugsDelivered          9.962613e-05
# Assignment             2.687996e-02
# ARRAY_INPUT            3.072606e-04
#
# [99 rows x 1 columns]
# ----------------------------------------------------
#
# ================  Feature Importance  ==============
# GradientBoostingRegressor
# ____________________________________________________
#                 GradientBoostingRegressor
# feature
# cInstr                       1.075316e-04
# VocabularySize               4.244686e-05
# V_VAL_9                      4.112026e-06
# V_VAL_8                      1.409994e-06
# V_VAL_7                      8.976714e-09
# ...                                   ...
# Column1                      4.673996e-02
# Bugs_Delivered               1.477117e-05
# BugsDelivered                9.839060e-06
# Assignment                   7.116856e-03
# ARRAY_INPUT                  3.140163e-07
#
# [99 rows x 1 columns]
# ----------------------------------------------------
# ================  Feature Importance  ==============
# AdaBoostRegressor
# ____________________________________________________
#                 AdaBoostRegressor
# feature
# cInstr               6.609621e-07
# VocabularySize       1.602346e-06
# V_VAL_9              0.000000e+00
# V_VAL_8              0.000000e+00
# V_VAL_7              0.000000e+00
# ...                           ...
# Column1              1.718443e-02
# Bugs_Delivered       1.753024e-06
# BugsDelivered        5.388758e-04
# Assignment           2.815767e-02
# ARRAY_INPUT          8.507480e-04
#
# [99 rows x 1 columns]
# ----------------------------------------------------
# C:\Users\vitto\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:386: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = self.plt.figure(figsize=self.figsize)
# ================  Feature Importance  ==============
# RandomForestRegressor
# ____________________________________________________
#                 RandomForestRegressor
# feature
# cInstr                       0.000075
# VocabularySize               0.000070
# V_VAL_9                      0.000032
# V_VAL_8                      0.000004
# V_VAL_7                      0.000003
# ...                               ...
# Column1                      0.011456
# Bugs_Delivered               0.000839
# BugsDelivered                0.002058
# Assignment                   0.018358
# ARRAY_INPUT                  0.000218
#
# [99 rows x 1 columns]
# ----------------------------------------------------
#                    ExtraTreesRegressor  GradientBoostingRegressor  \
# feature
# Column1                       0.023620               4.673996e-02
# BugsDelivered                 0.000100               9.839060e-06
# DifficultyLevel               0.000059               5.884981e-05
# DistinctOperands              0.000282               1.048213e-05
# DistinctOperators             0.034676               9.411042e-03
# ...                                ...                        ...
# M_VAL_28                      0.000005               5.154171e-06
# M_VAL_29                      0.000001               2.131863e-06
# M_VAL_30                      0.000010               2.255370e-06
# M_VAL_31                      0.000005               9.789138e-07
# M_VAL_32                      0.000018               6.668680e-06
#
#                    AdaBoostRegressor  RandomForestRegressor       sum  \
# feature
# Column1                 1.718443e-02               0.011456  3.022115
# BugsDelivered           5.388758e-04               0.002058  0.210506
# DifficultyLevel         2.103134e-09               0.000029  0.297205
# DistinctOperands        7.818398e-04               0.000048  0.431525
# DistinctOperators       2.478394e-02               0.141963  0.235084
# ...                              ...                    ...       ...
# M_VAL_28                0.000000e+00               0.000005  0.060336
# M_VAL_29                0.000000e+00               0.000002  0.030515
# M_VAL_30                0.000000e+00               0.000014  0.025500
# M_VAL_31                0.000000e+00               0.000002  0.057642
# M_VAL_32                0.000000e+00               0.000005  0.015174
#
#                         avg
# feature
# Column1            0.604423
# BugsDelivered      0.042101
# DifficultyLevel    0.059441
# DistinctOperands   0.086305
# DistinctOperators  0.047017
# ...                     ...
# M_VAL_28           0.012067
# M_VAL_29           0.006103
# M_VAL_30           0.005100
# M_VAL_31           0.011528
# M_VAL_32           0.003035
#
# [99 rows x 6 columns]
#
# =============   Feature Importance Mean Score   =============
#                         avg
# feature
# Column1            0.604423
# BugsDelivered      0.042101
# DifficultyLevel    0.059441
# DistinctOperands   0.086305
# DistinctOperators  0.047017
# ...                     ...
# M_VAL_28           0.012067
# M_VAL_29           0.006103
# M_VAL_30           0.005100
# M_VAL_31           0.011528
# M_VAL_32           0.003035
#
# [99 rows x 1 columns]
#
# =============   Feature Pruned by Score   =============
#                                       avg
# feature
# Column1                          0.604423
# DifficultyLevel                  0.059441
# DistinctOperands                 0.086305
# Sloc                             0.109766
# DecisionPoint                    0.146568
# GlobalVariables                  0.055153
# If                               0.124636
# Goto                             0.125674
# ExitPoint                        0.092638
# Function.1                       0.098542
# FunctionCall                     0.096065
# PointerDereferencing             0.381000
# CyclomaticComplexity             0.391519
# SyntacticallyReachableFunctions  0.166561
# SemanticallyReachedFunctions     0.108235
# ARRAY_INPUT                      0.407025
# cInstr                           0.050506
# SS_VAL_1                         0.062539
# ['Column1', 'DifficultyLevel', 'DistinctOperands', 'Sloc', 'DecisionPoint', 'GlobalVariables', 'If', 'Goto', 'ExitPoint', 'Function.1', 'FunctionCall', 'PointerDereferencing', 'CyclomaticComplexity', 'SyntacticallyReachableFunctions', 'SemanticallyReachedFunctions', 'ARRAY_INPUT', 'cInstr', 'SS_VAL_1']
#
# |------------------------------------|
#
# min_Slack
#
# |------------------------------------|
#
#
# ================  Feature Importance  ==============
# ExtraTreesRegressor
# ____________________________________________________
#                 ExtraTreesRegressor
# feature
# cInstr                 2.514839e-03
# VocabularySize         3.241598e-03
# V_VAL_9                2.199751e-17
# V_VAL_8                1.197823e-17
# V_VAL_7                2.224238e-17
# ...                             ...
# Column1                5.325240e-03
# Bugs_Delivered         3.614188e-03
# BugsDelivered          4.190911e-03
# Assignment             4.848861e-02
# ARRAY_INPUT            1.875760e-04
#
# [99 rows x 1 columns]
# ----------------------------------------------------
#
# ================  Feature Importance  ==============
# GradientBoostingRegressor
# ____________________________________________________
#                 GradientBoostingRegressor
# feature
# cInstr                       2.395460e-17
# VocabularySize               0.000000e+00
# V_VAL_9                      0.000000e+00
# V_VAL_8                     -2.653398e-17
# V_VAL_7                      1.114670e-18
# ...                                   ...
# Column1                      1.181176e-15
# Bugs_Delivered               1.901445e-04
# BugsDelivered                5.181035e-05
# Assignment                   0.000000e+00
# ARRAY_INPUT                  3.580459e-04
#
# [99 rows x 1 columns]
# ----------------------------------------------------
#
# ================  Feature Importance  ==============
# AdaBoostRegressor
# ____________________________________________________
#                 AdaBoostRegressor
# feature
# cInstr                        NaN
# VocabularySize                NaN
# V_VAL_9                       NaN
# V_VAL_8                       NaN
# V_VAL_7                       NaN
# ...                           ...
# Column1                       NaN
# Bugs_Delivered                NaN
# BugsDelivered                 NaN
# Assignment                    NaN
# ARRAY_INPUT                   NaN
#
# [99 rows x 1 columns]
# ----------------------------------------------------
# C:\Users\vitto\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py:303: RuntimeWarning: invalid value encountered in divide
#   sum(
# C:\Users\vitto\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py:303: RuntimeWarning: invalid value encountered in divide
#   sum(
# ================  Feature Importance  ==============
# RandomForestRegressor
# ____________________________________________________
#                 RandomForestRegressor
# feature
# cInstr                   9.937583e-18
# VocabularySize           1.291940e-18
# V_VAL_9                  2.723833e-17
# V_VAL_8                  2.526278e-17
# V_VAL_7                  2.771351e-17
# ...                               ...
# Column1                  3.386939e-17
# Bugs_Delivered           1.497222e-04
# BugsDelivered            2.211192e-04
# Assignment               0.000000e+00
# ARRAY_INPUT              1.487139e-04
#
# [99 rows x 1 columns]
# ----------------------------------------------------
#                    ExtraTreesRegressor  GradientBoostingRegressor  \
# feature
# Column1                       0.005325               1.181176e-15
# BugsDelivered                 0.004191               5.181035e-05
# DifficultyLevel               0.021634               0.000000e+00
# DistinctOperands              0.000026               0.000000e+00
# DistinctOperators             0.005555               1.387757e-17
# ...                                ...                        ...
# M_VAL_28                      0.000000               0.000000e+00
# M_VAL_29                      0.000000               0.000000e+00
# M_VAL_30                      0.000000               0.000000e+00
# M_VAL_31                      0.000000               0.000000e+00
# M_VAL_32                      0.000000               0.000000e+00
#
#                    AdaBoostRegressor  RandomForestRegressor       sum  \
# feature
# Column1                          NaN           3.386939e-17  3.631863
# BugsDelivered                    NaN           2.211192e-04  0.257071
# DifficultyLevel                  NaN           1.536625e-17  0.378280
# DistinctOperands                 NaN           5.215273e-18  0.517856
# DistinctOperators                NaN           0.000000e+00  0.287657
# ...                              ...                    ...       ...
# M_VAL_28                         NaN           0.000000e+00  0.072403
# M_VAL_29                         NaN           0.000000e+00  0.036617
# M_VAL_30                         NaN           0.000000e+00  0.030600
# M_VAL_31                         NaN           0.000000e+00  0.069170
# M_VAL_32                         NaN           0.000000e+00  0.018208
#
#                         avg
# feature
# Column1            0.726373
# BugsDelivered      0.051414
# DifficultyLevel    0.075656
# DistinctOperands   0.103571
# DistinctOperators  0.057531
# ...                     ...
# M_VAL_28           0.014481
# M_VAL_29           0.007323
# M_VAL_30           0.006120
# M_VAL_31           0.013834
# M_VAL_32           0.003642
#
# [99 rows x 6 columns]
#
# =============   Feature Importance Mean Score   =============
#                         avg
# feature
# Column1            0.726373
# BugsDelivered      0.051414
# DifficultyLevel    0.075656
# DistinctOperands   0.103571
# DistinctOperators  0.057531
# ...                     ...
# M_VAL_28           0.014481
# M_VAL_29           0.007323
# M_VAL_30           0.006120
# M_VAL_31           0.013834
# M_VAL_32           0.003642
#
# [99 rows x 1 columns]
#
# =============   Feature Pruned by Score   =============
#                                       avg
# feature
# Column1                          0.726373
# BugsDelivered                    0.051414
# DifficultyLevel                  0.075656
# DistinctOperands                 0.103571
# DistinctOperators                0.057531
# Total_Operands                   0.055962
# VocabularySize                   0.053037
# Sloc                             0.360901
# DecisionPoint                    0.190332
# GlobalVariables                  0.068029
# If                               0.160613
# Loop                             0.246361
# Goto                             0.150813
# Assignment                       0.063295
# ExitPoint                        0.113496
# Function.1                       0.124164
# FunctionCall                     0.121999
# PointerDereferencing             0.460457
# CyclomaticComplexity             0.482173
# SyntacticallyReachableFunctions  0.203733
# SemanticallyReachedFunctions     0.135516
# RANGE_SCALAR_VALUES              0.068905
# ARRAY_INPUT                      0.488568
# cInstr                           0.061111
# Bugs_Delivered                   0.053599
# SS_VAL_1                         0.075794
# M_VAL_3                          0.056489
# M_VAL_12                         0.053095
# ['Column1', 'BugsDelivered', 'DifficultyLevel', 'DistinctOperands', 'DistinctOperators', 'Total_Operands', 'VocabularySize', 'Sloc', 'DecisionPoint', 'GlobalVariables', 'If', 'Loop', 'Goto', 'Assignment', 'ExitPoint', 'Function.1', 'FunctionCall', 'PointerDereferencing', 'CyclomaticComplexity', 'SyntacticallyReachableFunctions', 'SemanticallyReachedFunctions', 'RANGE_SCALAR_VALUES', 'ARRAY_INPUT', 'cInstr', 'Bugs_Delivered', 'SS_VAL_1', 'M_VAL_3', 'M_VAL_12']
#
# |------------------------------------|
#
# Max_Freq
#
# |------------------------------------|
#
#
# ================  Feature Importance  ==============
# ExtraTreesRegressor
# ____________________________________________________
#                 ExtraTreesRegressor
# feature
# cInstr                 1.703841e-06
# VocabularySize         1.687463e-03
# V_VAL_9                1.194598e-07
# V_VAL_8                7.506438e-08
# V_VAL_7                2.658593e-07
# ...                             ...
# Column1                1.085299e-02
# Bugs_Delivered         1.780436e-06
# BugsDelivered          2.179496e-05
# Assignment             5.012823e-02
# ARRAY_INPUT            1.905190e-05
#
# [99 rows x 1 columns]
# ----------------------------------------------------
#
# ================  Feature Importance  ==============
# GradientBoostingRegressor
# ____________________________________________________
#                 GradientBoostingRegressor
# feature
# cInstr                       7.781118e-06
# VocabularySize               5.517264e-06
# V_VAL_9                      1.193022e-08
# V_VAL_8                      7.911343e-09
# V_VAL_7                      4.997144e-08
# ...                                   ...
# Column1                      4.776630e-05
# Bugs_Delivered               1.594660e-06
# BugsDelivered                1.354003e-06
# Assignment                   1.763083e-05
# ARRAY_INPUT                  0.000000e+00
#
# [99 rows x 1 columns]
# ----------------------------------------------------
#
# ================  Feature Importance  ==============
# AdaBoostRegressor
# ____________________________________________________
#                 AdaBoostRegressor
# feature
# cInstr               5.147200e-04
# VocabularySize       6.853158e-18
# V_VAL_9              1.291194e-17
# V_VAL_8              0.000000e+00
# V_VAL_7              5.229585e-18
# ...                           ...
# Column1              1.874279e-16
# Bugs_Delivered       5.529546e-17
# BugsDelivered        2.382295e-17
# Assignment           0.000000e+00
# ARRAY_INPUT          0.000000e+00
#
# [99 rows x 1 columns]
# ----------------------------------------------------
#
# ================  Feature Importance  ==============
# RandomForestRegressor
# ____________________________________________________
#                 RandomForestRegressor
# feature
# cInstr                   3.683282e-06
# VocabularySize           1.257523e-06
# V_VAL_9                  4.492964e-08
# V_VAL_8                  1.585529e-07
# V_VAL_7                  3.799946e-07
# ...                               ...
# Column1                  4.711918e-05
# Bugs_Delivered           1.335481e-06
# BugsDelivered            6.190543e-07
# Assignment               8.036730e-06
# ARRAY_INPUT              1.448107e-07
#
# [99 rows x 1 columns]
# ----------------------------------------------------
#                    ExtraTreesRegressor  GradientBoostingRegressor  \
# feature
# Column1                   1.085299e-02               4.776630e-05
# BugsDelivered             2.179496e-05               1.354003e-06
# DifficultyLevel           7.088212e-03               1.049621e-05
# DistinctOperands          6.215463e-05               6.596219e-06
# DistinctOperators         3.802263e-03               8.198293e-04
# ...                                ...                        ...
# M_VAL_28                  1.602805e-07               3.678997e-09
# M_VAL_29                  1.763484e-07               8.542525e-08
# M_VAL_30                  1.220569e-06               1.533795e-08
# M_VAL_31                  6.069797e-08               4.762136e-08
# M_VAL_32                  1.232722e-06               1.552679e-08
#
#                    AdaBoostRegressor  RandomForestRegressor       sum  \
# feature
# Column1                 1.874279e-16           4.711918e-05  4.369184
# BugsDelivered           2.382295e-17           6.190543e-07  0.308508
# DifficultyLevel         7.198377e-05           4.806227e-06  0.461112
# DistinctOperands        5.014514e-16           1.138029e-06  0.621497
# DistinctOperators       9.630572e-04           1.143157e-03  0.351916
# ...                              ...                    ...       ...
# M_VAL_28                0.000000e+00           1.688542e-07  0.086884
# M_VAL_29                0.000000e+00           1.020610e-07  0.043941
# M_VAL_30                0.000000e+00           1.501458e-07  0.036722
# M_VAL_31                0.000000e+00           1.262680e-07  0.083004
# M_VAL_32                1.193784e-16           1.377598e-07  0.021851
#
#                         avg
# feature
# Column1            0.873837
# BugsDelivered      0.061702
# DifficultyLevel    0.092222
# DistinctOperands   0.124299
# DistinctOperators  0.070383
# ...                     ...
# M_VAL_28           0.017377
# M_VAL_29           0.008788
# M_VAL_30           0.007344
# M_VAL_31           0.016601
# M_VAL_32           0.004370
#
# [99 rows x 6 columns]
# =============   Feature Importance Mean Score   =============
#                         avg
# feature
# Column1            0.873837
# BugsDelivered      0.061702
# DifficultyLevel    0.092222
# DistinctOperands   0.124299
# DistinctOperators  0.070383
# ...                     ...
# M_VAL_28           0.017377
# M_VAL_29           0.008788
# M_VAL_30           0.007344
# M_VAL_31           0.016601
# M_VAL_32           0.004370
#
# [99 rows x 1 columns]
#
# =============   Feature Pruned by Score   =============
#                                       avg
# feature
# Column1                          0.873837
# BugsDelivered                    0.061702
# DifficultyLevel                  0.092222
# DistinctOperands                 0.124299
# DistinctOperators                0.070383
# ProgramLength                    0.050248
# Total_Operands                   0.068256
# VocabularySize                   0.063983
# Sloc                             0.726470
# DecisionPoint                    0.234996
# GlobalVariables                  0.082256
# If                               0.214678
# Loop                             0.637360
# Goto                             0.185725
# Assignment                       0.085985
# ExitPoint                        0.137689
# Function.1                       0.153913
# FunctionCall                     0.148188
# PointerDereferencing             0.555988
# CyclomaticComplexity             0.592448
# SyntacticallyReachableFunctions  0.246862
# SemanticallyReachedFunctions     0.168231
# SCALAR_INPUT                     0.063255
# RANGE_SCALAR_VALUES              0.105133
# ARRAY_INPUT                      0.586286
# cInstr                           0.073438
# Bugs_Delivered                   0.064319
# SS_VAL_1                         0.104032
# SV_VAL_1                         0.054317
# M_VAL_3                          0.067793
# M_VAL_12                         0.063714
# ['Column1', 'BugsDelivered', 'DifficultyLevel', 'DistinctOperands', 'DistinctOperators', 'ProgramLength', 'Total_Operands', 'VocabularySize', 'Sloc', 'DecisionPoint', 'GlobalVariables', 'If', 'Loop', 'Goto', 'Assignment', 'ExitPoint', 'Function.1', 'FunctionCall', 'PointerDereferencing', 'CyclomaticComplexity', 'SyntacticallyReachableFunctions', 'SemanticallyReachedFunctions', 'SCALAR_INPUT', 'RANGE_SCALAR_VALUES', 'ARRAY_INPUT', 'cInstr', 'Bugs_Delivered', 'SS_VAL_1', 'SV_VAL_1', 'M_VAL_3', 'M_VAL_12']
#
# |------------------------------------|
#
# clockCycles
#
# |------------------------------------|
#
#
# ================  Feature Importance  ==============
# ExtraTreesRegressor
# ____________________________________________________
#                 ExtraTreesRegressor
# feature
# cInstr                 4.274930e-01
# VocabularySize         1.891585e-03
# V_VAL_9                1.912323e-06
# V_VAL_8                1.577204e-07
# V_VAL_7                1.345152e-06
# ...                             ...
# Column1                1.901597e-02
# Bugs_Delivered         2.532080e-02
# BugsDelivered          1.467315e-02
# Assignment             1.669428e-02
# ARRAY_INPUT            1.450029e-05
#
# [99 rows x 1 columns]
# ----------------------------------------------------
#
# ================  Feature Importance  ==============
# GradientBoostingRegressor
# ____________________________________________________
#                 GradientBoostingRegressor
# feature
# cInstr                       6.516494e-01
# VocabularySize               2.990126e-03
# V_VAL_9                      3.177559e-07
# V_VAL_8                      1.077861e-08
# V_VAL_7                      2.190318e-07
# ...                                   ...
# Column1                      2.392414e-02
# Bugs_Delivered               4.747354e-03
# BugsDelivered                1.481132e-02
# Assignment                   8.741155e-07
# ARRAY_INPUT                  0.000000e+00
#
# [99 rows x 1 columns]
# ----------------------------------------------------
#
# ================  Feature Importance  ==============
# AdaBoostRegressor
# ____________________________________________________
#                 AdaBoostRegressor
# feature
# cInstr                   0.634558
# VocabularySize           0.001239
# V_VAL_9                  0.000000
# V_VAL_8                  0.000000
# V_VAL_7                  0.000000
# ...                           ...
# Column1                  0.010893
# Bugs_Delivered           0.023021
# BugsDelivered            0.010394
# Assignment               0.000000
# ARRAY_INPUT              0.000000
#
# [99 rows x 1 columns]
# ----------------------------------------------------
#
# ================  Feature Importance  ==============
# RandomForestRegressor
# ____________________________________________________
#                 RandomForestRegressor
# feature
# cInstr                   6.499049e-01
# VocabularySize           1.815392e-03
# V_VAL_9                  5.136578e-07
# V_VAL_8                  1.505817e-06
# V_VAL_7                  1.723587e-06
# ...                               ...
# Column1                  5.455471e-03
# Bugs_Delivered           8.161612e-03
# BugsDelivered            1.116488e-02
# Assignment               2.588443e-04
# ARRAY_INPUT              6.217832e-08
#
# [99 rows x 1 columns]
# ----------------------------------------------------
#                    ExtraTreesRegressor  GradientBoostingRegressor  \
# feature
# Column1                       0.019016                   0.023924
# BugsDelivered                 0.014673                   0.014811
# DifficultyLevel               0.007064                   0.008463
# DistinctOperands              0.003191                   0.006337
# DistinctOperators             0.013482                   0.000017
# ...                                ...                        ...
# M_VAL_28                      0.001242                   0.000095
# M_VAL_29                      0.000107                   0.000012
# M_VAL_30                      0.049387                   0.002936
# M_VAL_31                      0.000040                   0.000001
# M_VAL_32                      0.000966                   0.000713
#
#                    AdaBoostRegressor  RandomForestRegressor       sum  \
# feature
# Column1                     0.010893               0.005455  5.302309
# BugsDelivered               0.010394               0.011165  0.421254
# DifficultyLevel             0.005847               0.005802  0.580510
# DistinctOperands            0.005101               0.003954  0.764380
# DistinctOperators           0.000157               0.000302  0.436257
# ...                              ...                    ...       ...
# M_VAL_28                    0.000000               0.000853  0.106451
# M_VAL_29                    0.000000               0.000123  0.052973
# M_VAL_30                    0.002564               0.006461  0.105415
# M_VAL_31                    0.000000               0.000220  0.099866
# M_VAL_32                    0.000471               0.000901  0.029274
#
#                         avg
# feature
# Column1            1.060462
# BugsDelivered      0.084251
# DifficultyLevel    0.116102
# DistinctOperands   0.152876
# DistinctOperators  0.087251
# ...                     ...
# M_VAL_28           0.021290
# M_VAL_29           0.010595
# M_VAL_30           0.021083
# M_VAL_31           0.019973
# M_VAL_32           0.005855
#
# [99 rows x 6 columns]
#
# =============   Feature Importance Mean Score   =============
#                         avg
# feature
# Column1            1.060462
# BugsDelivered      0.084251
# DifficultyLevel    0.116102
# DistinctOperands   0.152876
# DistinctOperators  0.087251
# ...                     ...
# M_VAL_28           0.021290
# M_VAL_29           0.010595
# M_VAL_30           0.021083
# M_VAL_31           0.019973
# M_VAL_32           0.005855
#
# [99 rows x 1 columns]
#
# =============   Feature Pruned by Score   =============
#                                       avg
# feature
# Column1                          1.060462
# BugsDelivered                    0.084251
# DifficultyLevel                  0.116102
# DistinctOperands                 0.152876
# DistinctOperators                0.087251
# ProgramLength                    0.072800
# ProgramVolume                    0.070716
# TimeToImplement                  0.052040
# TotalOperators                   0.063981
# Total_Operands                   0.104336
# VocabularySize                   0.078367
# Sloc                             0.875922
# DecisionPoint                    0.286986
# GlobalVariables                  0.099204
# If                               0.261113
# Loop                             0.767727
# Goto                             0.223044
# Assignment                       0.106573
# ExitPoint                        0.165639
# Function.1                       0.185600
# FunctionCall                     0.178866
# PointerDereferencing             0.667635
# CyclomaticComplexity             0.712841
# SyntacticallyReachableFunctions  0.296986
# SemanticallyReachedFunctions     0.203783
# CoverageEstimation               0.058929
# SCALAR_INPUT                     0.075958
# RANGE_SCALAR_VALUES              0.126231
# ARRAY_INPUT                      0.703546
# cInstr                           0.560847
# Bugs_Delivered                   0.089433
# SS_VAL_1                         0.247671
# SV_VAL_1                         0.065322
# V_VAL_22                         0.050565
# M_VAL_3                          0.081505
# M_VAL_12                         0.078021
# ['Column1', 'BugsDelivered', 'DifficultyLevel', 'DistinctOperands', 'DistinctOperators', 'ProgramLength', 'ProgramVolume', 'TimeToImplement', 'TotalOperators', 'Total_Operands', 'VocabularySize', 'Sloc', 'DecisionPoint', 'GlobalVariables', 'If', 'Loop', 'Goto', 'Assignment', 'ExitPoint', 'Function.1', 'FunctionCall', 'PointerDereferencing', 'CyclomaticComplexity', 'SyntacticallyReachableFunctions', 'SemanticallyReachedFunctions', 'CoverageEstimation', 'SCALAR_INPUT', 'RANGE_SCALAR_VALUES', 'ARRAY_INPUT', 'cInstr', 'Bugs_Delivered', 'SS_VAL_1', 'SV_VAL_1', 'V_VAL_22', 'M_VAL_3', 'M_VAL_12']
