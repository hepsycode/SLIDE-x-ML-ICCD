# %%
# import modules 
import matplotlib.pyplot as mp 
import pandas as pd 
import seaborn as sns 
import numpy as np
from pylab import savefig

# %%
# import file with data 
data=pd.read_csv("Dataset/csv/Train/BambuTrainTest-Zynq-7000.csv") 
saveFolderImg = "Heatmap-Zynq-7000/"

# %%
# DSP
DSP_code = data.iloc[:, np.r_[6, 14:48]] # Code Features
DSP_array = data.iloc[:, np.r_[6, 52:83]] # Code Features
DSP_matrix = data.iloc[:, np.r_[6, 84:115]] # Code Features
# print(DSP_matrix)

# %%
# Calculate the correlation matrix
correlation_matrix = DSP_code.corr()

# Create the heatmap
mp.figure(figsize = (10,8))

# plotting correlation heatmap 
sns_plot = sns.heatmap(correlation_matrix, cmap='coolwarm', linecolor='white', linewidths=1) 

sns_plot.set_xticklabels(sns_plot.get_xmajorticklabels(), fontsize = 9)
sns_plot.set_yticklabels(sns_plot.get_ymajorticklabels(), fontsize = 9)

# sns.set(font_scale=1)
sns_plot.figure.savefig(saveFolderImg+'DSP_code.png', dpi=300, bbox_inches='tight')

correlation_matrix.to_csv(saveFolderImg+'DSP_code.csv')
  
# displaying heatmap 
# mp.show()

# %%
# Calculate the correlation matrix
correlation_matrix = DSP_array.corr()

# Create the heatmap
mp.figure(figsize = (10,8))

# plotting correlation heatmap 
sns_plot = sns.heatmap(correlation_matrix, cmap='coolwarm', linecolor='white', linewidths=1) 

sns_plot.set_xticklabels(sns_plot.get_xmajorticklabels(), fontsize = 9)
sns_plot.set_yticklabels(sns_plot.get_ymajorticklabels(), fontsize = 9)

# sns.set(font_scale=1)
sns_plot.figure.savefig(saveFolderImg+'DSP_array.png', dpi=300, bbox_inches='tight')

correlation_matrix.to_csv(saveFolderImg+'DSP_array.csv')
  
# displaying heatmap 
# mp.show()

# %%
# Calculate the correlation matrix
correlation_matrix = DSP_matrix.corr()

# Create the heatmap
mp.figure(figsize = (10,8))

# plotting correlation heatmap 
sns_plot = sns.heatmap(correlation_matrix, cmap='coolwarm', linecolor='white', linewidths=1) 

sns_plot.set_xticklabels(sns_plot.get_xmajorticklabels(), fontsize = 9)
sns_plot.set_yticklabels(sns_plot.get_ymajorticklabels(), fontsize = 9)

# sns.set(font_scale=1)
sns_plot.figure.savefig(saveFolderImg+'DSP_matrix.png', dpi=300, bbox_inches='tight')

correlation_matrix.to_csv(saveFolderImg+'DSP_matrix.csv')
  
# displaying heatmap 
# mp.show()

# %%
# BRAM
BRAM_code = data.iloc[:, np.r_[7, 14:48]] # Code Features
BRAM_array = data.iloc[:, np.r_[7, 52:83]] # Code Features
BRAM_matrix = data.iloc[:, np.r_[7, 84:115]] # Code Features

# %%
# Calculate the correlation matrix
correlation_matrix = BRAM_code.corr()

# Create the heatmap
mp.figure(figsize = (10,8))

# plotting correlation heatmap 
sns_plot = sns.heatmap(correlation_matrix, cmap='coolwarm', linecolor='white', linewidths=1) 

sns_plot.set_xticklabels(sns_plot.get_xmajorticklabels(), fontsize = 9)
sns_plot.set_yticklabels(sns_plot.get_ymajorticklabels(), fontsize = 9)

# sns.set(font_scale=1)
sns_plot.figure.savefig(saveFolderImg+'BRAM_code.png', dpi=300, bbox_inches='tight')

correlation_matrix.to_csv(saveFolderImg+'BRAM_code.csv')
  
# displaying heatmap 
# mp.show()

# %%
# Calculate the correlation matrix
correlation_matrix = BRAM_array.corr()

# Create the heatmap
mp.figure(figsize = (10,8))

# plotting correlation heatmap 
sns_plot = sns.heatmap(correlation_matrix, cmap='coolwarm', linecolor='white', linewidths=1) 

sns_plot.set_xticklabels(sns_plot.get_xmajorticklabels(), fontsize = 9)
sns_plot.set_yticklabels(sns_plot.get_ymajorticklabels(), fontsize = 9)

# sns.set(font_scale=1)
sns_plot.figure.savefig(saveFolderImg+'BRAM_array.png', dpi=300, bbox_inches='tight')

correlation_matrix.to_csv(saveFolderImg+'BRAM_array.csv')
  
# displaying heatmap 
# mp.show()

# %%
# Calculate the correlation matrix
correlation_matrix = BRAM_matrix.corr()

# Create the heatmap
mp.figure(figsize = (10,8))

# plotting correlation heatmap 
sns_plot = sns.heatmap(correlation_matrix, cmap='coolwarm', linecolor='white', linewidths=1) 

sns_plot.set_xticklabels(sns_plot.get_xmajorticklabels(), fontsize = 9)
sns_plot.set_yticklabels(sns_plot.get_ymajorticklabels(), fontsize = 9)

# sns.set(font_scale=1)
sns_plot.figure.savefig(saveFolderImg+'BRAM_matrix.png', dpi=300, bbox_inches='tight')

correlation_matrix.to_csv(saveFolderImg+'BRAM_matrix.csv')
  
# displaying heatmap 
# mp.show()

# %%
# FF
FF_code = data.iloc[:, np.r_[8, 14:48]] # Code Features
FF_array = data.iloc[:, np.r_[8, 52:83]] # Code Features
FF_matrix = data.iloc[:, np.r_[8, 84:115]] # Code Features

# %%
# Calculate the correlation matrix
correlation_matrix = FF_code.corr()

# Create the heatmap
mp.figure(figsize = (10,8))

# plotting correlation heatmap 
sns_plot = sns.heatmap(correlation_matrix, cmap='coolwarm', linecolor='white', linewidths=1) 

sns_plot.set_xticklabels(sns_plot.get_xmajorticklabels(), fontsize = 9)
sns_plot.set_yticklabels(sns_plot.get_ymajorticklabels(), fontsize = 9)

# sns.set(font_scale=1)
sns_plot.figure.savefig(saveFolderImg+'FF_code.png', dpi=300, bbox_inches='tight')

correlation_matrix.to_csv(saveFolderImg+'FF_code.csv')
  
# displaying heatmap 
# mp.show()

# %%
# Calculate the correlation matrix
correlation_matrix = FF_array.corr()

# Create the heatmap
mp.figure(figsize = (10,8))

# plotting correlation heatmap 
sns_plot = sns.heatmap(correlation_matrix, cmap='coolwarm', linecolor='white', linewidths=1) 

sns_plot.set_xticklabels(sns_plot.get_xmajorticklabels(), fontsize = 9)
sns_plot.set_yticklabels(sns_plot.get_ymajorticklabels(), fontsize = 9)

# sns.set(font_scale=1)
sns_plot.figure.savefig(saveFolderImg+'FF_array.png', dpi=300, bbox_inches='tight')

correlation_matrix.to_csv(saveFolderImg+'FF_array.csv')
  
# displaying heatmap 
# mp.show()

# %%
# Calculate the correlation matrix
correlation_matrix = FF_matrix.corr()

# Create the heatmap
mp.figure(figsize = (10,8))

# plotting correlation heatmap 
sns_plot = sns.heatmap(correlation_matrix, cmap='coolwarm', linecolor='white', linewidths=1) 

sns_plot.set_xticklabels(sns_plot.get_xmajorticklabels(), fontsize = 9)
sns_plot.set_yticklabels(sns_plot.get_ymajorticklabels(), fontsize = 9)

# sns.set(font_scale=1)
sns_plot.figure.savefig(saveFolderImg+'FF_matrix.png', dpi=300, bbox_inches='tight')

correlation_matrix.to_csv(saveFolderImg+'FF_matrix.csv')
  
# displaying heatmap 
# mp.show()

# %%
# LUT
LUT_code = data.iloc[:, np.r_[9, 14:48]] # Code Features
LUT_array = data.iloc[:, np.r_[9, 52:83]] # Code Features
LUT_matrix = data.iloc[:, np.r_[9, 84:115]] # Code Features

# %%
# Calculate the correlation matrix
correlation_matrix = LUT_code.corr()

# Create the heatmap
mp.figure(figsize = (10,8))

# plotting correlation heatmap 
sns_plot = sns.heatmap(correlation_matrix, cmap='coolwarm', linecolor='white', linewidths=1) 

sns_plot.set_xticklabels(sns_plot.get_xmajorticklabels(), fontsize = 9)
sns_plot.set_yticklabels(sns_plot.get_ymajorticklabels(), fontsize = 9)

# sns.set(font_scale=1)
sns_plot.figure.savefig(saveFolderImg+'LUT_code.png', dpi=300, bbox_inches='tight')

correlation_matrix.to_csv(saveFolderImg+'LUT_code.csv')
  
# displaying heatmap 
# mp.show()

# %%
# Calculate the correlation matrix
correlation_matrix = LUT_array.corr()

# Create the heatmap
mp.figure(figsize = (10,8))

# plotting correlation heatmap 
sns_plot = sns.heatmap(correlation_matrix, cmap='coolwarm', linecolor='white', linewidths=1) 

sns_plot.set_xticklabels(sns_plot.get_xmajorticklabels(), fontsize = 9)
sns_plot.set_yticklabels(sns_plot.get_ymajorticklabels(), fontsize = 9)

# sns.set(font_scale=1)
sns_plot.figure.savefig(saveFolderImg+'LUT_array.png', dpi=300, bbox_inches='tight')

correlation_matrix.to_csv(saveFolderImg+'LUT_array.csv')
  
# displaying heatmap 
# mp.show()

# %%
# Calculate the correlation matrix
correlation_matrix = LUT_matrix.corr()

# Create the heatmap
mp.figure(figsize = (10,8))

# plotting correlation heatmap 
sns_plot = sns.heatmap(correlation_matrix, cmap='coolwarm', linecolor='white', linewidths=1) 

sns_plot.set_xticklabels(sns_plot.get_xmajorticklabels(), fontsize = 9)
sns_plot.set_yticklabels(sns_plot.get_ymajorticklabels(), fontsize = 9)

# sns.set(font_scale=1)
sns_plot.figure.savefig(saveFolderImg+'LUT_matrix.png', dpi=300, bbox_inches='tight')

correlation_matrix.to_csv(saveFolderImg+'LUT_matrix.csv')
  
# displaying heatmap 
# mp.show()

# %%
# Min Slack
Slack_code = data.iloc[:, np.r_[10, 14:48]] # Code Features
Slack_array = data.iloc[:, np.r_[10, 52:83]] # Code Features
Slack_matrix = data.iloc[:, np.r_[10, 84:115]] # Code Features

# %%
# Calculate the correlation matrix
correlation_matrix = Slack_code.corr()

# Create the heatmap
mp.figure(figsize = (10,8))

# plotting correlation heatmap 
sns_plot = sns.heatmap(correlation_matrix, cmap='coolwarm', linecolor='white', linewidths=1) 

sns_plot.set_xticklabels(sns_plot.get_xmajorticklabels(), fontsize = 9)
sns_plot.set_yticklabels(sns_plot.get_ymajorticklabels(), fontsize = 9)

# sns.set(font_scale=1)
sns_plot.figure.savefig(saveFolderImg+'Slack_code.png', dpi=300, bbox_inches='tight')

correlation_matrix.to_csv(saveFolderImg+'Slack_code.csv')
  
# displaying heatmap 
# mp.show()

# %%
# Calculate the correlation matrix
correlation_matrix = Slack_array.corr()

# Create the heatmap
mp.figure(figsize = (10,8))

# plotting correlation heatmap 
sns_plot = sns.heatmap(correlation_matrix, cmap='coolwarm', linecolor='white', linewidths=1) 

sns_plot.set_xticklabels(sns_plot.get_xmajorticklabels(), fontsize = 9)
sns_plot.set_yticklabels(sns_plot.get_ymajorticklabels(), fontsize = 9)

# sns.set(font_scale=1)
sns_plot.figure.savefig(saveFolderImg+'Slack_array.png', dpi=300, bbox_inches='tight')

correlation_matrix.to_csv(saveFolderImg+'Slack_array.csv')
  
# displaying heatmap 
# mp.show()

# %%
# Calculate the correlation matrix
correlation_matrix = Slack_matrix.corr()

# Create the heatmap
mp.figure(figsize = (10,8))

# plotting correlation heatmap 
sns_plot = sns.heatmap(correlation_matrix, cmap='coolwarm', linecolor='white', linewidths=1) 

sns_plot.set_xticklabels(sns_plot.get_xmajorticklabels(), fontsize = 9)
sns_plot.set_yticklabels(sns_plot.get_ymajorticklabels(), fontsize = 9)

# sns.set(font_scale=1)
sns_plot.figure.savefig(saveFolderImg+'Slack_matrix.png', dpi=300, bbox_inches='tight')

correlation_matrix.to_csv(saveFolderImg+'Slack_matrix.csv')
  
# displaying heatmap 
# mp.show()

# %%
# Max Freq.
Freq_code = data.iloc[:, np.r_[11, 14:48]] # Code Features
Freq_array = data.iloc[:, np.r_[11, 52:83]] # Code Features
Freq_matrix = data.iloc[:, np.r_[11, 84:115]] # Code Features

# %%
# Calculate the correlation matrix
correlation_matrix = Freq_code.corr()

# Create the heatmap
mp.figure(figsize = (10,8))

# plotting correlation heatmap 
sns_plot = sns.heatmap(correlation_matrix, cmap='coolwarm', linecolor='white', linewidths=1) 

sns_plot.set_xticklabels(sns_plot.get_xmajorticklabels(), fontsize = 9)
sns_plot.set_yticklabels(sns_plot.get_ymajorticklabels(), fontsize = 9)

# sns.set(font_scale=1)
sns_plot.figure.savefig(saveFolderImg+'Freq_code.png', dpi=300, bbox_inches='tight')

correlation_matrix.to_csv(saveFolderImg+'Freq_code.csv')
  
# displaying heatmap 
# mp.show()

# %%
# Calculate the correlation matrix
correlation_matrix = Freq_array.corr()

# Create the heatmap
mp.figure(figsize = (10,8))

# plotting correlation heatmap 
sns_plot = sns.heatmap(correlation_matrix, cmap='coolwarm', linecolor='white', linewidths=1) 

sns_plot.set_xticklabels(sns_plot.get_xmajorticklabels(), fontsize = 9)
sns_plot.set_yticklabels(sns_plot.get_ymajorticklabels(), fontsize = 9)

# sns.set(font_scale=1)
sns_plot.figure.savefig(saveFolderImg+'Freq_array.png', dpi=300, bbox_inches='tight')

correlation_matrix.to_csv(saveFolderImg+'Freq_array.csv')
  
# displaying heatmap 
# mp.show()

# %%
# Calculate the correlation matrix
correlation_matrix = Freq_matrix.corr()

# Create the heatmap
mp.figure(figsize = (10,8))

# plotting correlation heatmap 
sns_plot = sns.heatmap(correlation_matrix, cmap='coolwarm', linecolor='white', linewidths=1) 

sns_plot.set_xticklabels(sns_plot.get_xmajorticklabels(), fontsize = 9)
sns_plot.set_yticklabels(sns_plot.get_ymajorticklabels(), fontsize = 9)

# sns.set(font_scale=1)
sns_plot.figure.savefig(saveFolderImg+'Freq_matrix.png', dpi=300, bbox_inches='tight')

correlation_matrix.to_csv(saveFolderImg+'Freq_matrix.csv')
  
# displaying heatmap 
# mp.show()

# %%
# Clock Cycles
CC_code = data.iloc[:, np.r_[49, 14:48]] # Code Features
CC_array = data.iloc[:, np.r_[49, 52:83]] # Code Features
CC_matrix = data.iloc[:, np.r_[49, 84:115]] # Code Features

# %%
# Calculate the correlation matrix
correlation_matrix = CC_code.corr()

# Create the heatmap
mp.figure(figsize = (10,8))

# plotting correlation heatmap 
sns_plot = sns.heatmap(correlation_matrix, cmap='coolwarm', linecolor='white', linewidths=1) 

sns_plot.set_xticklabels(sns_plot.get_xmajorticklabels(), fontsize = 9)
sns_plot.set_yticklabels(sns_plot.get_ymajorticklabels(), fontsize = 9)

# sns.set(font_scale=1)
sns_plot.figure.savefig(saveFolderImg+'CC_code.png', dpi=300, bbox_inches='tight')

correlation_matrix.to_csv(saveFolderImg+'CC_code.csv')
  
# displaying heatmap 
# mp.show()

# %%
# Calculate the correlation matrix
correlation_matrix = CC_array.corr()

# Create the heatmap
mp.figure(figsize = (10,8))

# plotting correlation heatmap 
sns_plot = sns.heatmap(correlation_matrix, cmap='coolwarm', linecolor='white', linewidths=1) 

sns_plot.set_xticklabels(sns_plot.get_xmajorticklabels(), fontsize = 9)
sns_plot.set_yticklabels(sns_plot.get_ymajorticklabels(), fontsize = 9)

# sns.set(font_scale=1)
sns_plot.figure.savefig(saveFolderImg+'CC_array.png', dpi=300, bbox_inches='tight')

correlation_matrix.to_csv(saveFolderImg+'CC_array.csv')
  
# displaying heatmap 
# mp.show()

# %%
# Calculate the correlation matrix
correlation_matrix = CC_matrix.corr()

# Create the heatmap
mp.figure(figsize = (10,8))

# plotting correlation heatmap 
sns_plot = sns.heatmap(correlation_matrix, cmap='coolwarm', linecolor='white', linewidths=1) 

sns_plot.set_xticklabels(sns_plot.get_xmajorticklabels(), fontsize = 9)
sns_plot.set_yticklabels(sns_plot.get_ymajorticklabels(), fontsize = 9)

# sns.set(font_scale=1)
sns_plot.figure.savefig(saveFolderImg+'CC_matrix.png', dpi=300, bbox_inches='tight')

correlation_matrix.to_csv(saveFolderImg+'CC_matrix.csv')
  
# displaying heatmap 
# mp.show()
